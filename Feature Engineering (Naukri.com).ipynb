# %%
# Importing all the necessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Now read the data 
df=pd.read_csv(r'D:\Akshay\Python Projects\Naukri.com Analysis\Datasets\naukri_com-job_sample.csv')

# %%
# Lets take a lookat the data columns available
df.columns
# Out:
# Index(['company', 'education', 'experience', 'industry', 'jobdescription',
#        'jobid', 'joblocation_address', 'jobtitle', 'numberofpositions',
#        'payrate', 'postdate', 'site_name', 'skills', 'uniq_id'],
#       dtype='object')

# %%
df.shape
# Out:
# (22000, 14)

# %%
# Lets see how many records are missing for each column
count_missing=df.isnull().sum()
count_missing
# Out:
# company                    4
# education               1996
# experience                 4
# industry                   5
# jobdescription             4
# jobid                      0
# joblocation_address      501
# jobtitle                   0
# numberofpositions      17536
# payrate                   97
# postdate                  23
# site_name              18013
# skills                   528
# uniq_id                    0
# dtype: int64

# %%
# Now we will identify what percent of records are blank for each column
percent_missing=count_missing*100/len(df)
percent_missing
# Out:
# company                 0.018182
# education               9.072727
# experience              0.018182
# industry                0.022727
# jobdescription          0.018182
# jobid                   0.000000
# joblocation_address     2.277273
# jobtitle                0.000000
# numberofpositions      79.709091
# payrate                 0.440909
# postdate                0.104545
# site_name              81.877273
# skills                  2.400000
# uniq_id                 0.000000
# dtype: float64

# %%
# We can show both number of missing values and percent as part of dataframe

missing_values_df=pd.DataFrame({'count_missing':count_missing,
                           'percent_missing':percent_missing})

# %%
missing_values_df.style.background_gradient()
# Out:
# <style type="text/css">
# #T_09a8b_row0_col0, #T_09a8b_row0_col1, #T_09a8b_row2_col0, #T_09a8b_row2_col1, #T_09a8b_row3_col0, #T_09a8b_row3_col1, #T_09a8b_row4_col0, #T_09a8b_row4_col1, #T_09a8b_row5_col0, #T_09a8b_row5_col1, #T_09a8b_row7_col0, #T_09a8b_row7_col1, #T_09a8b_row10_col0, #T_09a8b_row10_col1, #T_09a8b_row13_col0, #T_09a8b_row13_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_09a8b_row1_col0, #T_09a8b_row1_col1 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_09a8b_row6_col0, #T_09a8b_row6_col1, #T_09a8b_row12_col0, #T_09a8b_row12_col1 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_09a8b_row8_col0, #T_09a8b_row8_col1 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_09a8b_row9_col0, #T_09a8b_row9_col1 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_09a8b_row11_col0, #T_09a8b_row11_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_09a8b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_09a8b_level0_col0" class="col_heading level0 col0" >count_missing</th>
#       <th id="T_09a8b_level0_col1" class="col_heading level0 col1" >percent_missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09a8b_level0_row0" class="row_heading level0 row0" >company</th>
#       <td id="T_09a8b_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_09a8b_row0_col1" class="data row0 col1" >0.018182</td>
#     </tr>
#     <tr>
#       <th id="T_09a8b_level0_row1" class="row_heading level0 row1" >education</th>
#       <td id="T_09a8b_row1_col0" class="data row1 col0" >1996</td>
#       <td id="T_09a8b_row1_col1" class="data row1 col1" >9.072727</td>
#     </tr>
#     <tr>
#       <th id="T_09a8b_level0_row2" class="row_heading level0 row2" >experience</th>
#       <td id="T_09a8b_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_09a8b_row2_col1" class="data row2 col1" >0.018182</td>
#     </tr>
#     <tr>
#       <th id="T_09a8b_level0_row3" class="row_heading level0 row3" >industry</th>
#       <td id="T_09a8b_row3_col0" class="data row3 col0" >5</td>
#       <td id="T_09a8b_row3_col1" class="data row3 col1" >0.022727</td>
#     </tr>
#     <tr>
#       <th id="T_09a8b_level0_row4" class="row_heading level0 row4" >jobdescription</th>
#       <td id="T_09a8b_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_09a8b_row4_col1" class="data row4 col1" >0.018182</td>
#     </tr>
#     <tr>
#       <th id="T_09a8b_level0_row5" class="row_heading level0 row5" >jobid</th>
#       <td id="T_09a8b_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_09a8b_row5_col1" class="data row5 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_09a8b_level0_row6" class="row_heading level0 row6" >joblocation_address</th>
#       <td id="T_09a8b_row6_col0" class="data row6 col0" >501</td>
#       <td id="T_09a8b_row6_col1" class="data row6 col1" >2.277273</td>
#     </tr>
#     <tr>
#       <th id="T_09a8b_level0_row7" class="row_heading level0 row7" >jobtitle</th>
#       <td id="T_09a8b_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_09a8b_row7_col1" class="data row7 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_09a8b_level0_row8" class="row_heading level0 row8" >numberofpositions</th>
#       <td id="T_09a8b_row8_col0" class="data row8 col0" >17536</td>
#       <td id="T_09a8b_row8_col1" class="data row8 col1" >79.709091</td>
#     </tr>
#     <tr>
#       <th id="T_09a8b_level0_row9" class="row_heading level0 row9" >payrate</th>
#       <td id="T_09a8b_row9_col0" class="data row9 col0" >97</td>
#       <td id="T_09a8b_row9_col1" class="data row9 col1" >0.440909</td>
#     </tr>
#     <tr>
#       <th id="T_09a8b_level0_row10" class="row_heading level0 row10" >postdate</th>
#       <td id="T_09a8b_row10_col0" class="data row10 col0" >23</td>
#       <td id="T_09a8b_row10_col1" class="data row10 col1" >0.104545</td>
#     </tr>
#     <tr>
#       <th id="T_09a8b_level0_row11" class="row_heading level0 row11" >site_name</th>
#       <td id="T_09a8b_row11_col0" class="data row11 col0" >18013</td>
#       <td id="T_09a8b_row11_col1" class="data row11 col1" >81.877273</td>
#     </tr>
#     <tr>
#       <th id="T_09a8b_level0_row12" class="row_heading level0 row12" >skills</th>
#       <td id="T_09a8b_row12_col0" class="data row12 col0" >528</td>
#       <td id="T_09a8b_row12_col1" class="data row12 col1" >2.400000</td>
#     </tr>
#     <tr>
#       <th id="T_09a8b_level0_row13" class="row_heading level0 row13" >uniq_id</th>
#       <td id="T_09a8b_row13_col0" class="data row13 col0" >0</td>
#       <td id="T_09a8b_row13_col1" class="data row13 col1" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
#  #### Unique Values
#  - Now we will try to find the unique values in each column
#  - We can do this either by using for loop or by using List Comprehension

# %%
for col in df.columns:
    print('{} has {} unique values'.format(col,df[col].nunique()))
# Out:
# company has 8469 unique values
# education has 2355 unique values
# experience has 147 unique values
# industry has 63 unique values
# jobdescription has 21063 unique values
# jobid has 21910 unique values
# joblocation_address has 2329 unique values
# jobtitle has 17564 unique values
# numberofpositions has 84 unique values
# payrate has 1848 unique values
# postdate has 4203 unique values
# site_name has 1 unique values
# skills has 45 unique values
# uniq_id has 22000 unique values

# %%
unique=[]
for col in df.columns:
    unique.append([col,df[col].nunique(),df[col].unique()])

# %%
unique
# Out:
# [['company',
#   8469,
#   array(['MM Media Pvt Ltd', 'find live infotech',
#          'Softtech Career Infosystem Pvt. Ltd', ...,
#          'TeamLease Services Limited hiring for BPA Solution Architect',
#          'Austere Technology Solutions', 'Musk - Startup'], dtype=object)],
#  ['education',
#   2355,
#   array(['UG: B.Tech/B.E. - Any Specialization PG:Any Postgraduate - Any Specialization, Post Graduation Not Required',
#          'UG: B.Tech/B.E. - Any Specialization PG:MBA/PGDM - Any Specialization',
#          'UG: Any Graduate - Any Specialization PG:Any Postgraduate Doctorate:Doctorate Not Required',
#          ..., 'PG:MS/M.Sc(Science) - Any Specialization, Statistics',
#          'UG: B.Tech/B.E. - Any Specialization PG:MCA - Computers, M.Tech - Any Specialization, MS/M.Sc(Science) - Any Specialization Doctorate:Doctorate Not Required',
#          'UG: B.Tech/B.E. - Computers PG:MS/M.Sc(Science) - Computers Doctorate:Doctorate Not Required'],
#         dtype=object)],
#  ['experience',
#   147,
#   array(['0 - 1 yrs', '0 - 0 yrs', '4 - 8 yrs', '11 - 15 yrs', '6 - 8 yrs',
#          '2 - 5 yrs', '1 - 3 yrs', '2 - 7 yrs', '1 - 5 yrs', '2 - 4 yrs',
#          '3 - 8 yrs', '5 - 7 yrs', '1 - 2 yrs', '5 - 10 yrs', '6 - 10 yrs',
#          '10 - 12 yrs', '4 - 6 yrs', '1 - 6 yrs', '3 - 6 yrs', '3 - 7 yrs',
#          '4 - 9 yrs', '3 - 5 yrs', '0 - 5 yrs', '5 - 8 yrs', '9 - 12 yrs',
#          '7 - 12 yrs', '10 - 15 yrs', '4 - 7 yrs', '8 - 12 yrs',
#          '10 - 16 yrs', '5 - 9 yrs', '0 - 4 yrs', '10 - 20 yrs',
#          '10 - 18 yrs', '0 - 2 yrs', '7 - 10 yrs', '6 - 11 yrs',
#          '2 - 3 yrs', '1 - 4 yrs', '7 - 9 yrs', '8 - 13 yrs', '2 - 6 yrs',
#          '8 - 10 yrs', '0 - 3 yrs', '6 - 9 yrs', '15 - 20 yrs',
#          '12 - 16 yrs', '1 - 1 yrs', '3 - 4 yrs', '17 - 20 yrs',
#          '10 - 17 yrs', '9 - 14 yrs', '13 - 15 yrs', '17 - 23 yrs',
#          '15 - 25 yrs', '14 - 22 yrs', '4 - 5 yrs', '7 - 11 yrs',
#          '16 - 24 yrs', '14 - 18 yrs', '12 - 15 yrs', '7 - 8 yrs',
#          '5 - 6 yrs', '12 - 19 yrs', '20 - 25 yrs', '10 - 13 yrs',
#          '12 - 18 yrs', '6 - 7 yrs', '10 - 14 yrs', '12 - 20 yrs',
#          'Not Mentioned', '11 - 16 yrs', '15 - 17 yrs', '20 - 30 yrs',
#          '15 - 21 yrs', '8 - 11 yrs', '8 - 9 yrs', '9 - 13 yrs',
#          '15 - 22 yrs', '14 - 19 yrs', '13 - 19 yrs', '15 - 16 yrs',
#          '14 - 20 yrs', '11 - 12 yrs', '1 - 8 yrs', '9 - 11 yrs',
#          '15 - 18 yrs', '4 - 10 yrs', '10 - 11 yrs', '12 - 22 yrs',
#          '7 - 16 yrs', '16 - 18 yrs', '13 - 17 yrs', '13 - 20 yrs',
#          '5 - 5 yrs', '1 - 10 yrs', '12 - 14 yrs', '5 - 15 yrs',
#          '11 - 17 yrs', nan, '16 - 20 yrs', '13 - 23 yrs', '3 - 3 yrs',
#          '18 - 20 yrs', '23 - 30 yrs', '14 - 24 yrs', '18 - 28 yrs',
#          '11 - 21 yrs', '15 - 19 yrs', '18 - 22 yrs', '6 - 12 yrs',
#          '14 - 17 yrs', '12 - 17 yrs', '13 - 18 yrs', '25 - 30 yrs',
#          '11 - 14 yrs', '2 - 8 yrs', '2 - 10 yrs', '4 - 11 yrs',
#          '11 - 13 yrs', '14 - 16 yrs', '2 - 2 yrs', '10 - 19 yrs',
#          '14 - 15 yrs', '2 - 9 yrs', '13 - 16 yrs', '7 - 7 yrs',
#          '9 - 10 yrs', '11 - 20 yrs', '12 - 13 yrs', '15 - 24 yrs',
#          '3 - -1 yrs', '10 - 10 yrs', '26 - 30 yrs', '7 - 14 yrs',
#          '11 - 19 yrs', '16 - 25 yrs', '11 - 18 yrs', '18 - 25 yrs',
#          '17 - 25 yrs', '18 - 21 yrs', '18 - 23 yrs', '20 - 24 yrs',
#          '20 - 23 yrs', '3 - 10 yrs', '17 - 27 yrs', '16 - 26 yrs',
#          '13 - 22 yrs'], dtype=object)],
#  ['industry',
#   63,
#   array(['Media / Entertainment / Internet',
#          'Advertising / PR / MR / Event Management',
#          'IT-Software / Software Services',
#          'Banking / Financial Services / Broking',
#          'Aviation / Aerospace Firms',
#          'Industrial Products / Heavy Machinery', 'FMCG / Foods / Beverage',
#          'Recruitment / Staffing', 'Internet / Ecommerce',
#          'Travel / Hotels / Restaurants / Airlines / Railways',
#          'BPO / Call Centre / ITES', 'Pharma / Biotech / Clinical Research',
#          'Real Estate / Property', 'Insurance', 'Facility Management',
#          'Publishing', 'Education / Teaching / Training',
#          'Retail / Wholesale',
#          'Automobile / Auto Anciliary / Auto Components',
#          'Chemicals / PetroChemical / Plastic / Rubber',
#          'Government / Defence', 'Accounting / Finance',
#          'Textiles / Garments / Accessories',
#          'Semiconductors / Electronics', 'Telecom/ISP',
#          'Medical / Healthcare / Hospitals', 'Legal',
#          'Courier / Transportation / Freight / Warehousing',
#          'NGO / Social Services / Regulators / Industry Associations',
#          'Other', 'Architecture / Interior Design',
#          'KPO / Research / Analytics',
#          'Construction / Engineering / Cement / Metals',
#          'Office Equipment / Automation',
#          'Consumer Electronics / Appliances / Durables', 'Iron and Steel',
#          'Strategy / Management Consulting Firms',
#          'Oil and Gas / Energy / Power / Infrastructure',
#          'IT-Hardware & Networking', 'Wellness / Fitness / Sports / Beauty',
#          'Agriculture / Dairy', 'Electricals / Switchgears',
#          'Security / Law Enforcement', 'Gems / Jewellery',
#          'Ceramics / Sanitary ware', 'Fresher / Trainee / Entry Level',
#          'Food Processing', 'Printing / Packaging', 'Brewery / Distillery',
#          'Telecom/ISP /', 'Export / Import',
#          'Heat Ventilation / Air Conditioning',
#          'Wellness / Fitness / Sports',
#          'Water Treatment / Waste Management', nan, 'Shipping / Marine',
#          'Glass / Glassware', 'Animation / Gaming',
#          'Fertilizers / Pesticides', 'Pulp and Paper', 'Tyres', 'Leather',
#          'Broadcasting', 'Medical Devices / Equipments'], dtype=object)],
#  ['jobdescription',
#   21063,
#   array(['Job Description \xa0 Send me Jobs like this Qualifications: - == > 10th To Graduation & Any Skill: - == > Basic Computer Knowledge Job Requirement : - == > System or Laptop Type of job: - == > Full Time or Part time Languages : - == > Tamil & English. Experience : - == > Freshers & Experience payment details: - 1 form per day 5/- 10 form per day 50/- 100 form per day 500/- monthly you can earn 15000/- per month Selection Process: - == > Easy Selection Process,So What Are You Waiting For? Apply Now & Grab Best Opportunity To Make Your Carrier & To Improve Your Earing Skills. More detail contact Mr Hari 8678902528 9003010282 Salary:INR 1,50,000 - 2,25,000 P.A Industry: Media / Entertainment / Internet Functional Area: ITES , BPO , KPO , LPO , Customer Service , Operations Role Category:Other Role:Fresher Keyskills English Typing Part Time Data Entry Selection Process Desired Candidate Profile Education- UG: B.Tech/B.E. - Any Specialization PG:Any Postgraduate - Any Specialization, Post Graduation Not Required Please refer to the Job description above Company Profile: MM Media Pvt Ltd Mass Media International Find Live Info Pvt Ltd DATA SERVICES is established in the year 2012 with a vision of transforming an ordinary to extra ordinary thing. Find live info is one of our main project, it is a developing search engine site based at Chennai, India. With years of experience, we have crafted massive data collection job opportunities for public. FIND LIVE INFO a blend of experience, imagination, strategy and action to create digital experience that excite, challenge, inspire and engage users. FIND LIVE INFO provides other business opportunities which will be handled by experts of various fields. We have interesting combination of young and experienced Specialists Under the guidance of our Top Management we bloom towards success More detail contect 8678902528 Download PPT Photo 1 \xa0 View Contact Details',
#          'Job Description \xa0 Send me Jobs like this Qualifications: - == > 10th To Graduation & Any Skill: - == > Basic Computer Knowledge Job Requirement : - == > System or Laptop Type of job: - == > Full Time or Part time Languages : - == > Tamil & English. Experience : - == > Freshers & Experience payment details: - 1 form per day 5/- 10 form per day 50/- 100 form per day 500/- monthly you can earn 15000/- per month Selection Process: - == > Easy Selection Process,So What Are You Waiting For? Apply Now & Grab Best Opportunity To Make Your Carrier & To Improve Your Earing Skills. Chennai Peoples Only Contact Deepika Team Leader 9087728815 / 9087726713 Salary:INR 1,50,000 - 2,50,000 P.A. 20000 Industry: Advertising / PR / MR / Event Management Functional Area: Marketing , Advertising , MR , PR , Media Planning Role Category:Online/Digital Marketing Role:Search Engine Marketing/SEM Specialist Keyskills Data Entry data processing Desired Candidate Profile Education- UG: B.Tech/B.E. - Any Specialization PG:MBA/PGDM - Any Specialization Please refer to the Job description above Company Profile: find live infotech Find Live Infotech is one of our main projects, it is a developing search engine site based at chennai , India. With years of experience , we have crafted massive data collection job oppurtunties for public. Find live infotech provides other business opportunities which will be handled by experts of various fields Download PPT Photo 1 \xa0 View Contact Details',
#          'Job Description \xa0 Send me Jobs like this - as a developer in providing application design guidance and consultation, utilizing a thorough understanding of applicable technology, tools and existing designs. - Analyzes highly complex business requirements, designs and writes technical specifications to design or redesign complex computer platforms and applications. - Provides coding direction to less experienced staff or develops highly complex original code. - Acts as an expert technical resource for modeling, simulation and analysis efforts. - Verifies program logic by overseeing the preparation of test data, testing and debugging of programs. - Oversees overall systems testing and the migration of platforms and applications to production. - Develops new documentation, departmental technical procedures and user guides. - Leads projects, allocates and manages resources and manages the work of less experienced staff. - Assures quality, security and compliance requirements are met for supported area and oversees creation of or updates to and testing of the business continuation plan.: 7+ years application development and implementation experience. Additional Job Details: - Looking for PL/SQL developer, who has experience loading data using SQL loader. Salary: Not Disclosed by Recruiter Industry: IT-Software / Software Services Functional Area: IT Software - Application Programming , Maintenance Role Category:Programming & Design Role:Software Developer Keyskills SQL Loader PL SQL Development PLSQL Procedures Application Design Test Data Application Development Desired Candidate Profile \xa0 Education- UG: Any Graduate - Any Specialization PG:Any Postgraduate Doctorate:Doctorate Not Required Company Profile: Softtech Career Infosystem Pvt. Ltd Leading client of Softtech Career Infosystem Pvt. Ltd Download PPT Photo 1 \xa0 View Contact Details',
#          ...,
#          'Job Description \xa0 Send me Jobs like this Work with tech lead to architect and develop a full stack of functionalities, from scratch Design and own product components, from initial technology to scale Write high performing code that deploys to production multiple times a day Make key architectural decisions as well as solve scaling challenges Collaborate with the team and communicate effectively, to solve problems and build, extend, optimize and refactor the back-end architecture Salary: Not Disclosed by Recruiter Industry: Internet / Ecommerce Functional Area: IT Software - Application Programming , Maintenance Role Category:Programming & Design Role:Software Developer Keyskills Design Solutions Python Java Javascript HTML CSS Node.js PostgreSQL jQuery EC2 DynamoDB RDS SNS SQS S3 EMR Desired Candidate Profile Strong understanding and experience in any one of core back-end programming language (Java, C++, Python etc.) Strong understanding of Object-Oriented Programming. Strong understanding of algorithms and data structures. Understanding and experience of working with mid to large scale SQL database systems (MySQL, PostgreSQL, Microsoft-SQL etc). User authentication and authorization between multiple systems, servers, and environments. Familiarity with framework tools: spring, REST services. Knowledge in HTML, CSS, JavaScript, jQuery. Understanding of Node.js and web frameworks for Node.js (expressjs etc.) Understanding of code versioning tools, such as Git. Comfortable working within non-GUI linux shell environments. Familiarity with AWS products - EC2, DynamoDB, RDS, SNS, SQS, S3, EMR etc. The right candidate loves programming, ships code to production quickly and is passionate about building products for web & mobile.Skills: Python, Java, Javascript, HTML, CSS, Node.js, PostgreSQL, AWS/EC2/ELB/S3/DynamoDB Education- UG: B.Tech/B.E. - Any Specialization PG:Any Postgraduate Doctorate:Doctorate Not Required Company Profile: Musk - Startup Musk is an invoice discounting platform that partners with medium and large corporates to finance their SME vendors against approved invoices. The platform manages entire life cycle of loan- from sourcing to servicing. Data-driven intelligent on-boarding, diligence, and process automation renders invoice discounting programs scalable and safe for lending partners. Download PPT Photo 1 \xa0 View Contact Details',
#          'Job Description \xa0 Send me Jobs like this We are looking for a Senior UI Developers and Technical leads for a leading IT MNC at Delhi/NCR. Role : Senior Developer / Technical Lead / Manager Location: Delhi/ NCR SKILL REQUIREMENTS : - Expertise in HTML5 / CSS, JQuery, Javascript. - Hands on experience in Object Oriented Java script, AngularJS, BackboneJS. - The candidate should be willing to work as an individual contributor. - The candidate will be mainly involved in Design and development of Web/UI content. He should be dynamic and flexible. - Exposure in basic UI tools like HTML/CSS is must. Salary: Not Disclosed by Recruiter Industry: IT-Software / Software Services Functional Area: IT Software - Application Programming , Maintenance Role Category:Programming & Design Role:Team Lead/Technical Lead Keyskills Javascript HTML CSS UI Development JQuery Java Web Technologies Web UI Design Development Desired Candidate Profile EXPERIENCE : 7-13 yrsEducation : Btech / MCA / ME Education- UG: B.Tech/B.E. - Any Specialization PG:MCA - Computers, M.Tech - Any Specialization Doctorate:Doctorate Not Required Company Profile: Confidential Leading client Download PPT Photo 1 \xa0 View Contact Details',
#          'Job Description \xa0 Send me Jobs like this Job description : Experience of 5-10 years with most of this experience in Wireless (LTE/3G/2G) RF firmware development and will be an individual contributor. He/She should have the ability to Develop, enhance, troubleshoot of RF control firmware Participate in Baseband-RFIC interface bring-up of radio boards Develop manufacturing test firmware for RF boards Creation/customization of calibration and verification routines. Work closely with LTE baseband and RF hardware teams for RF firmware integration and testing Coach and mentor team mates and groom them to reach their goals. Support pre and post sales activities. Specific Knowledge/Skills Strong experience in development, customization of RF driver firmware Strong understanding of integrated RFIC based RF hardware Strong experience with developing and optimizing RF calibration and verification routines Proficient in C. Experience with configuration management and bug tracking systems Excellent communication skills Experience working both independently and in a team-oriented, collaborative environment is essential. Salary:INR 12,00,000 - 22,00,000 P.A Industry: IT-Software / Software Services Functional Area: IT Software - System Programming Role Category:Programming & Design Role:Software Developer Keyskills 2G 3G LTE C Optimization RF Post Sales Communication Skills Bug Tracking Firmware Development Desired Candidate Profile Please refer to the Job description above Education- UG: B.Tech/B.E. - Any Specialization PG:MCA - Computers, M.Tech - Any Specialization Company Profile: Cambio Consulting India Pvt Ltd Product MNC Download PPT Photo 1 \xa0 View Contact Details'],
#         dtype=object)],
#  ['jobid',
#   21910,
#   array([210516002263, 210516002391, 101016900534, ..., 251116900644,
#          231116901329, 251116003840], dtype=int64)],
#  ['joblocation_address',
#   2329,
#   array(['Chennai', 'Bengaluru',
#          'Mumbai, Bengaluru, Kolkata, Chennai, Coimbatore, Tamilnadu', ...,
#          'Mumbai, Bengaluru, Hyderabad, Kolkata',
#          'Mumbai, Chennai, Delhi, Bengaluru, Hyderabad, Pune',
#          'Bengaluru, Malaysia'], dtype=object)],
#  ['jobtitle',
#   17564,
#   array(['Walkin Data Entry Operator (night Shift)',
#          'Work Based Onhome Based Part Time.', 'Pl/sql Developer - SQL',
#          ..., 'Full Stack Development Engineer',
#          'Sr UI Developer/ Technical Lead - Html/ CSS/ Javascript/ Angularjs',
#          'RF Firmware Engineers'], dtype=object)],
#  ['numberofpositions',
#   84,
#   array([     nan, 6.00e+01, 4.00e+00, 2.00e+00, 2.00e+01, 3.00e+00,
#          1.00e+00, 7.00e+02, 8.00e+00, 5.00e+00, 7.00e+00, 2.50e+01,
#          1.00e+01, 6.50e+02, 1.50e+01, 5.00e+01, 3.00e+01, 6.00e+00,
#          4.50e+01, 1.30e+01, 1.00e+02, 2.70e+01, 2.20e+01, 1.90e+01,
#          1.10e+01, 9.00e+00, 3.60e+01, 9.90e+01, 1.80e+01, 7.00e+01,
#          4.90e+01, 3.50e+01, 5.20e+01, 1.25e+02, 2.00e+02, 1.20e+03,
#          1.40e+01, 1.20e+01, 3.80e+01, 5.00e+02, 4.00e+01, 1.00e+03,
#          4.00e+02, 1.50e+02, 4.30e+01, 7.50e+01, 5.50e+01, 2.50e+02,
#          3.00e+02, 5.70e+01, 6.00e+02, 8.60e+01, 3.40e+01, 8.80e+01,
#          8.90e+01, 9.50e+01, 3.50e+02, 3.20e+01, 7.40e+01, 8.70e+01,
#          2.40e+01, 7.80e+01, 6.80e+01, 6.50e+01, 9.80e+01, 7.60e+01,
#          9.20e+01, 2.05e+02, 8.00e+01, 5.60e+01, 6.40e+01, 7.30e+01,
#          3.10e+01, 9.60e+01, 1.70e+01, 4.70e+01, 9.00e+01, 2.30e+01,
#          5.50e+02, 9.00e+02, 1.60e+01, 2.00e+03, 2.90e+01, 4.10e+01,
#          1.26e+02])],
#  ['payrate',
#   1848,
#   array(['1,50,000 - 2,25,000 P.A', '1,50,000 - 2,50,000 P.A. 20000',
#          'Not Disclosed by Recruiter', ...,
#          '35,00,000 - 50,00,000 P.A. Compensation: Best in Industry',
#          '15,00,000 - 30,00,000 P.A. Salary is open',
#          '8,50,000 - 14,00,000 P.A'], dtype=object)],
#  ['postdate',
#   4203,
#   array(['2016-05-21 19:30:00 +0000', '2016-10-13 16:20:55 +0000',
#          '2016-10-13 16:20:56 +0000', ..., '2016-12-29 22:47:05 +0000',
#          '2016-11-24 22:47:05 +0000', '2016-11-27 22:47:05 +0000'],
#         dtype=object)],
#  ['site_name', 1, array([nan, 'www.naukri.com'], dtype=object)],
#  ['skills',
#   45,
#   array(['ITES', 'Marketing', 'IT Software - Application Programming',
#          'Accounts', 'Production', 'Sales', 'IT Software - Other',
#          'Executive Assistant', 'IT Software - Mobile',
#          'Engineering Design', 'Financial Services', 'Hotels',
#          'IT Software - QA & Testing', 'HR', 'Supply Chain',
#          'IT Software - Network Administration', 'Architecture', 'Legal',
#          'Site Engineering', 'Journalism', nan, 'IT Software - DBA',
#          'Strategy', 'Medical', 'Design', 'Defence Forces',
#          'IT Software - Mainframe', 'IT Software - Telecom Software',
#          'IT Software - Embedded', 'IT Software - Middleware', 'Teaching',
#          'IT Software - System Programming',
#          'IT Software - Client/Server Programming', 'Travel',
#          'IT Software - eCommerce', 'TV', 'Fashion Designing',
#          'IT Software - ERP', 'IT Hardware',
#          'Analytics & Business Intelligence', 'Beauty/Fitness/Spa Services',
#          'Top Management', 'Export', 'IT Software - Systems', 'Packaging',
#          'Shipping'], dtype=object)],
#  ['uniq_id',
#   22000,
#   array(['43b19632647068535437c774b6ca6cf8',
#          'd4c72325e57f89f364812b5ed5a795f0',
#          'c47df6f4cfdf5b46f1fd713ba61b9eba', ...,
#          'f6f2885a6c87572616fb766029a0d284',
#          'c6f6538cb1007dd02c1b4b77909b3d38',
#          '74fec26df6e1c0be0171311a2f03f180'], dtype=object)]]

# %% [markdown]
# - Finding unique values using List Comprehension

# %%
unique_df=[[col,df[col].nunique(),df[col].unique()] for col in df.columns]
unique_df
# Out:
# [['company',
#   8469,
#   array(['MM Media Pvt Ltd', 'find live infotech',
#          'Softtech Career Infosystem Pvt. Ltd', ...,
#          'TeamLease Services Limited hiring for BPA Solution Architect',
#          'Austere Technology Solutions', 'Musk - Startup'], dtype=object)],
#  ['education',
#   2355,
#   array(['UG: B.Tech/B.E. - Any Specialization PG:Any Postgraduate - Any Specialization, Post Graduation Not Required',
#          'UG: B.Tech/B.E. - Any Specialization PG:MBA/PGDM - Any Specialization',
#          'UG: Any Graduate - Any Specialization PG:Any Postgraduate Doctorate:Doctorate Not Required',
#          ..., 'PG:MS/M.Sc(Science) - Any Specialization, Statistics',
#          'UG: B.Tech/B.E. - Any Specialization PG:MCA - Computers, M.Tech - Any Specialization, MS/M.Sc(Science) - Any Specialization Doctorate:Doctorate Not Required',
#          'UG: B.Tech/B.E. - Computers PG:MS/M.Sc(Science) - Computers Doctorate:Doctorate Not Required'],
#         dtype=object)],
#  ['experience',
#   147,
#   array(['0 - 1 yrs', '0 - 0 yrs', '4 - 8 yrs', '11 - 15 yrs', '6 - 8 yrs',
#          '2 - 5 yrs', '1 - 3 yrs', '2 - 7 yrs', '1 - 5 yrs', '2 - 4 yrs',
#          '3 - 8 yrs', '5 - 7 yrs', '1 - 2 yrs', '5 - 10 yrs', '6 - 10 yrs',
#          '10 - 12 yrs', '4 - 6 yrs', '1 - 6 yrs', '3 - 6 yrs', '3 - 7 yrs',
#          '4 - 9 yrs', '3 - 5 yrs', '0 - 5 yrs', '5 - 8 yrs', '9 - 12 yrs',
#          '7 - 12 yrs', '10 - 15 yrs', '4 - 7 yrs', '8 - 12 yrs',
#          '10 - 16 yrs', '5 - 9 yrs', '0 - 4 yrs', '10 - 20 yrs',
#          '10 - 18 yrs', '0 - 2 yrs', '7 - 10 yrs', '6 - 11 yrs',
#          '2 - 3 yrs', '1 - 4 yrs', '7 - 9 yrs', '8 - 13 yrs', '2 - 6 yrs',
#          '8 - 10 yrs', '0 - 3 yrs', '6 - 9 yrs', '15 - 20 yrs',
#          '12 - 16 yrs', '1 - 1 yrs', '3 - 4 yrs', '17 - 20 yrs',
#          '10 - 17 yrs', '9 - 14 yrs', '13 - 15 yrs', '17 - 23 yrs',
#          '15 - 25 yrs', '14 - 22 yrs', '4 - 5 yrs', '7 - 11 yrs',
#          '16 - 24 yrs', '14 - 18 yrs', '12 - 15 yrs', '7 - 8 yrs',
#          '5 - 6 yrs', '12 - 19 yrs', '20 - 25 yrs', '10 - 13 yrs',
#          '12 - 18 yrs', '6 - 7 yrs', '10 - 14 yrs', '12 - 20 yrs',
#          'Not Mentioned', '11 - 16 yrs', '15 - 17 yrs', '20 - 30 yrs',
#          '15 - 21 yrs', '8 - 11 yrs', '8 - 9 yrs', '9 - 13 yrs',
#          '15 - 22 yrs', '14 - 19 yrs', '13 - 19 yrs', '15 - 16 yrs',
#          '14 - 20 yrs', '11 - 12 yrs', '1 - 8 yrs', '9 - 11 yrs',
#          '15 - 18 yrs', '4 - 10 yrs', '10 - 11 yrs', '12 - 22 yrs',
#          '7 - 16 yrs', '16 - 18 yrs', '13 - 17 yrs', '13 - 20 yrs',
#          '5 - 5 yrs', '1 - 10 yrs', '12 - 14 yrs', '5 - 15 yrs',
#          '11 - 17 yrs', nan, '16 - 20 yrs', '13 - 23 yrs', '3 - 3 yrs',
#          '18 - 20 yrs', '23 - 30 yrs', '14 - 24 yrs', '18 - 28 yrs',
#          '11 - 21 yrs', '15 - 19 yrs', '18 - 22 yrs', '6 - 12 yrs',
#          '14 - 17 yrs', '12 - 17 yrs', '13 - 18 yrs', '25 - 30 yrs',
#          '11 - 14 yrs', '2 - 8 yrs', '2 - 10 yrs', '4 - 11 yrs',
#          '11 - 13 yrs', '14 - 16 yrs', '2 - 2 yrs', '10 - 19 yrs',
#          '14 - 15 yrs', '2 - 9 yrs', '13 - 16 yrs', '7 - 7 yrs',
#          '9 - 10 yrs', '11 - 20 yrs', '12 - 13 yrs', '15 - 24 yrs',
#          '3 - -1 yrs', '10 - 10 yrs', '26 - 30 yrs', '7 - 14 yrs',
#          '11 - 19 yrs', '16 - 25 yrs', '11 - 18 yrs', '18 - 25 yrs',
#          '17 - 25 yrs', '18 - 21 yrs', '18 - 23 yrs', '20 - 24 yrs',
#          '20 - 23 yrs', '3 - 10 yrs', '17 - 27 yrs', '16 - 26 yrs',
#          '13 - 22 yrs'], dtype=object)],
#  ['industry',
#   63,
#   array(['Media / Entertainment / Internet',
#          'Advertising / PR / MR / Event Management',
#          'IT-Software / Software Services',
#          'Banking / Financial Services / Broking',
#          'Aviation / Aerospace Firms',
#          'Industrial Products / Heavy Machinery', 'FMCG / Foods / Beverage',
#          'Recruitment / Staffing', 'Internet / Ecommerce',
#          'Travel / Hotels / Restaurants / Airlines / Railways',
#          'BPO / Call Centre / ITES', 'Pharma / Biotech / Clinical Research',
#          'Real Estate / Property', 'Insurance', 'Facility Management',
#          'Publishing', 'Education / Teaching / Training',
#          'Retail / Wholesale',
#          'Automobile / Auto Anciliary / Auto Components',
#          'Chemicals / PetroChemical / Plastic / Rubber',
#          'Government / Defence', 'Accounting / Finance',
#          'Textiles / Garments / Accessories',
#          'Semiconductors / Electronics', 'Telecom/ISP',
#          'Medical / Healthcare / Hospitals', 'Legal',
#          'Courier / Transportation / Freight / Warehousing',
#          'NGO / Social Services / Regulators / Industry Associations',
#          'Other', 'Architecture / Interior Design',
#          'KPO / Research / Analytics',
#          'Construction / Engineering / Cement / Metals',
#          'Office Equipment / Automation',
#          'Consumer Electronics / Appliances / Durables', 'Iron and Steel',
#          'Strategy / Management Consulting Firms',
#          'Oil and Gas / Energy / Power / Infrastructure',
#          'IT-Hardware & Networking', 'Wellness / Fitness / Sports / Beauty',
#          'Agriculture / Dairy', 'Electricals / Switchgears',
#          'Security / Law Enforcement', 'Gems / Jewellery',
#          'Ceramics / Sanitary ware', 'Fresher / Trainee / Entry Level',
#          'Food Processing', 'Printing / Packaging', 'Brewery / Distillery',
#          'Telecom/ISP /', 'Export / Import',
#          'Heat Ventilation / Air Conditioning',
#          'Wellness / Fitness / Sports',
#          'Water Treatment / Waste Management', nan, 'Shipping / Marine',
#          'Glass / Glassware', 'Animation / Gaming',
#          'Fertilizers / Pesticides', 'Pulp and Paper', 'Tyres', 'Leather',
#          'Broadcasting', 'Medical Devices / Equipments'], dtype=object)],
#  ['jobdescription',
#   21063,
#   array(['Job Description \xa0 Send me Jobs like this Qualifications: - == > 10th To Graduation & Any Skill: - == > Basic Computer Knowledge Job Requirement : - == > System or Laptop Type of job: - == > Full Time or Part time Languages : - == > Tamil & English. Experience : - == > Freshers & Experience payment details: - 1 form per day 5/- 10 form per day 50/- 100 form per day 500/- monthly you can earn 15000/- per month Selection Process: - == > Easy Selection Process,So What Are You Waiting For? Apply Now & Grab Best Opportunity To Make Your Carrier & To Improve Your Earing Skills. More detail contact Mr Hari 8678902528 9003010282 Salary:INR 1,50,000 - 2,25,000 P.A Industry: Media / Entertainment / Internet Functional Area: ITES , BPO , KPO , LPO , Customer Service , Operations Role Category:Other Role:Fresher Keyskills English Typing Part Time Data Entry Selection Process Desired Candidate Profile Education- UG: B.Tech/B.E. - Any Specialization PG:Any Postgraduate - Any Specialization, Post Graduation Not Required Please refer to the Job description above Company Profile: MM Media Pvt Ltd Mass Media International Find Live Info Pvt Ltd DATA SERVICES is established in the year 2012 with a vision of transforming an ordinary to extra ordinary thing. Find live info is one of our main project, it is a developing search engine site based at Chennai, India. With years of experience, we have crafted massive data collection job opportunities for public. FIND LIVE INFO a blend of experience, imagination, strategy and action to create digital experience that excite, challenge, inspire and engage users. FIND LIVE INFO provides other business opportunities which will be handled by experts of various fields. We have interesting combination of young and experienced Specialists Under the guidance of our Top Management we bloom towards success More detail contect 8678902528 Download PPT Photo 1 \xa0 View Contact Details',
#          'Job Description \xa0 Send me Jobs like this Qualifications: - == > 10th To Graduation & Any Skill: - == > Basic Computer Knowledge Job Requirement : - == > System or Laptop Type of job: - == > Full Time or Part time Languages : - == > Tamil & English. Experience : - == > Freshers & Experience payment details: - 1 form per day 5/- 10 form per day 50/- 100 form per day 500/- monthly you can earn 15000/- per month Selection Process: - == > Easy Selection Process,So What Are You Waiting For? Apply Now & Grab Best Opportunity To Make Your Carrier & To Improve Your Earing Skills. Chennai Peoples Only Contact Deepika Team Leader 9087728815 / 9087726713 Salary:INR 1,50,000 - 2,50,000 P.A. 20000 Industry: Advertising / PR / MR / Event Management Functional Area: Marketing , Advertising , MR , PR , Media Planning Role Category:Online/Digital Marketing Role:Search Engine Marketing/SEM Specialist Keyskills Data Entry data processing Desired Candidate Profile Education- UG: B.Tech/B.E. - Any Specialization PG:MBA/PGDM - Any Specialization Please refer to the Job description above Company Profile: find live infotech Find Live Infotech is one of our main projects, it is a developing search engine site based at chennai , India. With years of experience , we have crafted massive data collection job oppurtunties for public. Find live infotech provides other business opportunities which will be handled by experts of various fields Download PPT Photo 1 \xa0 View Contact Details',
#          'Job Description \xa0 Send me Jobs like this - as a developer in providing application design guidance and consultation, utilizing a thorough understanding of applicable technology, tools and existing designs. - Analyzes highly complex business requirements, designs and writes technical specifications to design or redesign complex computer platforms and applications. - Provides coding direction to less experienced staff or develops highly complex original code. - Acts as an expert technical resource for modeling, simulation and analysis efforts. - Verifies program logic by overseeing the preparation of test data, testing and debugging of programs. - Oversees overall systems testing and the migration of platforms and applications to production. - Develops new documentation, departmental technical procedures and user guides. - Leads projects, allocates and manages resources and manages the work of less experienced staff. - Assures quality, security and compliance requirements are met for supported area and oversees creation of or updates to and testing of the business continuation plan.: 7+ years application development and implementation experience. Additional Job Details: - Looking for PL/SQL developer, who has experience loading data using SQL loader. Salary: Not Disclosed by Recruiter Industry: IT-Software / Software Services Functional Area: IT Software - Application Programming , Maintenance Role Category:Programming & Design Role:Software Developer Keyskills SQL Loader PL SQL Development PLSQL Procedures Application Design Test Data Application Development Desired Candidate Profile \xa0 Education- UG: Any Graduate - Any Specialization PG:Any Postgraduate Doctorate:Doctorate Not Required Company Profile: Softtech Career Infosystem Pvt. Ltd Leading client of Softtech Career Infosystem Pvt. Ltd Download PPT Photo 1 \xa0 View Contact Details',
#          ...,
#          'Job Description \xa0 Send me Jobs like this Work with tech lead to architect and develop a full stack of functionalities, from scratch Design and own product components, from initial technology to scale Write high performing code that deploys to production multiple times a day Make key architectural decisions as well as solve scaling challenges Collaborate with the team and communicate effectively, to solve problems and build, extend, optimize and refactor the back-end architecture Salary: Not Disclosed by Recruiter Industry: Internet / Ecommerce Functional Area: IT Software - Application Programming , Maintenance Role Category:Programming & Design Role:Software Developer Keyskills Design Solutions Python Java Javascript HTML CSS Node.js PostgreSQL jQuery EC2 DynamoDB RDS SNS SQS S3 EMR Desired Candidate Profile Strong understanding and experience in any one of core back-end programming language (Java, C++, Python etc.) Strong understanding of Object-Oriented Programming. Strong understanding of algorithms and data structures. Understanding and experience of working with mid to large scale SQL database systems (MySQL, PostgreSQL, Microsoft-SQL etc). User authentication and authorization between multiple systems, servers, and environments. Familiarity with framework tools: spring, REST services. Knowledge in HTML, CSS, JavaScript, jQuery. Understanding of Node.js and web frameworks for Node.js (expressjs etc.) Understanding of code versioning tools, such as Git. Comfortable working within non-GUI linux shell environments. Familiarity with AWS products - EC2, DynamoDB, RDS, SNS, SQS, S3, EMR etc. The right candidate loves programming, ships code to production quickly and is passionate about building products for web & mobile.Skills: Python, Java, Javascript, HTML, CSS, Node.js, PostgreSQL, AWS/EC2/ELB/S3/DynamoDB Education- UG: B.Tech/B.E. - Any Specialization PG:Any Postgraduate Doctorate:Doctorate Not Required Company Profile: Musk - Startup Musk is an invoice discounting platform that partners with medium and large corporates to finance their SME vendors against approved invoices. The platform manages entire life cycle of loan- from sourcing to servicing. Data-driven intelligent on-boarding, diligence, and process automation renders invoice discounting programs scalable and safe for lending partners. Download PPT Photo 1 \xa0 View Contact Details',
#          'Job Description \xa0 Send me Jobs like this We are looking for a Senior UI Developers and Technical leads for a leading IT MNC at Delhi/NCR. Role : Senior Developer / Technical Lead / Manager Location: Delhi/ NCR SKILL REQUIREMENTS : - Expertise in HTML5 / CSS, JQuery, Javascript. - Hands on experience in Object Oriented Java script, AngularJS, BackboneJS. - The candidate should be willing to work as an individual contributor. - The candidate will be mainly involved in Design and development of Web/UI content. He should be dynamic and flexible. - Exposure in basic UI tools like HTML/CSS is must. Salary: Not Disclosed by Recruiter Industry: IT-Software / Software Services Functional Area: IT Software - Application Programming , Maintenance Role Category:Programming & Design Role:Team Lead/Technical Lead Keyskills Javascript HTML CSS UI Development JQuery Java Web Technologies Web UI Design Development Desired Candidate Profile EXPERIENCE : 7-13 yrsEducation : Btech / MCA / ME Education- UG: B.Tech/B.E. - Any Specialization PG:MCA - Computers, M.Tech - Any Specialization Doctorate:Doctorate Not Required Company Profile: Confidential Leading client Download PPT Photo 1 \xa0 View Contact Details',
#          'Job Description \xa0 Send me Jobs like this Job description : Experience of 5-10 years with most of this experience in Wireless (LTE/3G/2G) RF firmware development and will be an individual contributor. He/She should have the ability to Develop, enhance, troubleshoot of RF control firmware Participate in Baseband-RFIC interface bring-up of radio boards Develop manufacturing test firmware for RF boards Creation/customization of calibration and verification routines. Work closely with LTE baseband and RF hardware teams for RF firmware integration and testing Coach and mentor team mates and groom them to reach their goals. Support pre and post sales activities. Specific Knowledge/Skills Strong experience in development, customization of RF driver firmware Strong understanding of integrated RFIC based RF hardware Strong experience with developing and optimizing RF calibration and verification routines Proficient in C. Experience with configuration management and bug tracking systems Excellent communication skills Experience working both independently and in a team-oriented, collaborative environment is essential. Salary:INR 12,00,000 - 22,00,000 P.A Industry: IT-Software / Software Services Functional Area: IT Software - System Programming Role Category:Programming & Design Role:Software Developer Keyskills 2G 3G LTE C Optimization RF Post Sales Communication Skills Bug Tracking Firmware Development Desired Candidate Profile Please refer to the Job description above Education- UG: B.Tech/B.E. - Any Specialization PG:MCA - Computers, M.Tech - Any Specialization Company Profile: Cambio Consulting India Pvt Ltd Product MNC Download PPT Photo 1 \xa0 View Contact Details'],
#         dtype=object)],
#  ['jobid',
#   21910,
#   array([210516002263, 210516002391, 101016900534, ..., 251116900644,
#          231116901329, 251116003840], dtype=int64)],
#  ['joblocation_address',
#   2329,
#   array(['Chennai', 'Bengaluru',
#          'Mumbai, Bengaluru, Kolkata, Chennai, Coimbatore, Tamilnadu', ...,
#          'Mumbai, Bengaluru, Hyderabad, Kolkata',
#          'Mumbai, Chennai, Delhi, Bengaluru, Hyderabad, Pune',
#          'Bengaluru, Malaysia'], dtype=object)],
#  ['jobtitle',
#   17564,
#   array(['Walkin Data Entry Operator (night Shift)',
#          'Work Based Onhome Based Part Time.', 'Pl/sql Developer - SQL',
#          ..., 'Full Stack Development Engineer',
#          'Sr UI Developer/ Technical Lead - Html/ CSS/ Javascript/ Angularjs',
#          'RF Firmware Engineers'], dtype=object)],
#  ['numberofpositions',
#   84,
#   array([     nan, 6.00e+01, 4.00e+00, 2.00e+00, 2.00e+01, 3.00e+00,
#          1.00e+00, 7.00e+02, 8.00e+00, 5.00e+00, 7.00e+00, 2.50e+01,
#          1.00e+01, 6.50e+02, 1.50e+01, 5.00e+01, 3.00e+01, 6.00e+00,
#          4.50e+01, 1.30e+01, 1.00e+02, 2.70e+01, 2.20e+01, 1.90e+01,
#          1.10e+01, 9.00e+00, 3.60e+01, 9.90e+01, 1.80e+01, 7.00e+01,
#          4.90e+01, 3.50e+01, 5.20e+01, 1.25e+02, 2.00e+02, 1.20e+03,
#          1.40e+01, 1.20e+01, 3.80e+01, 5.00e+02, 4.00e+01, 1.00e+03,
#          4.00e+02, 1.50e+02, 4.30e+01, 7.50e+01, 5.50e+01, 2.50e+02,
#          3.00e+02, 5.70e+01, 6.00e+02, 8.60e+01, 3.40e+01, 8.80e+01,
#          8.90e+01, 9.50e+01, 3.50e+02, 3.20e+01, 7.40e+01, 8.70e+01,
#          2.40e+01, 7.80e+01, 6.80e+01, 6.50e+01, 9.80e+01, 7.60e+01,
#          9.20e+01, 2.05e+02, 8.00e+01, 5.60e+01, 6.40e+01, 7.30e+01,
#          3.10e+01, 9.60e+01, 1.70e+01, 4.70e+01, 9.00e+01, 2.30e+01,
#          5.50e+02, 9.00e+02, 1.60e+01, 2.00e+03, 2.90e+01, 4.10e+01,
#          1.26e+02])],
#  ['payrate',
#   1848,
#   array(['1,50,000 - 2,25,000 P.A', '1,50,000 - 2,50,000 P.A. 20000',
#          'Not Disclosed by Recruiter', ...,
#          '35,00,000 - 50,00,000 P.A. Compensation: Best in Industry',
#          '15,00,000 - 30,00,000 P.A. Salary is open',
#          '8,50,000 - 14,00,000 P.A'], dtype=object)],
#  ['postdate',
#   4203,
#   array(['2016-05-21 19:30:00 +0000', '2016-10-13 16:20:55 +0000',
#          '2016-10-13 16:20:56 +0000', ..., '2016-12-29 22:47:05 +0000',
#          '2016-11-24 22:47:05 +0000', '2016-11-27 22:47:05 +0000'],
#         dtype=object)],
#  ['site_name', 1, array([nan, 'www.naukri.com'], dtype=object)],
#  ['skills',
#   45,
#   array(['ITES', 'Marketing', 'IT Software - Application Programming',
#          'Accounts', 'Production', 'Sales', 'IT Software - Other',
#          'Executive Assistant', 'IT Software - Mobile',
#          'Engineering Design', 'Financial Services', 'Hotels',
#          'IT Software - QA & Testing', 'HR', 'Supply Chain',
#          'IT Software - Network Administration', 'Architecture', 'Legal',
#          'Site Engineering', 'Journalism', nan, 'IT Software - DBA',
#          'Strategy', 'Medical', 'Design', 'Defence Forces',
#          'IT Software - Mainframe', 'IT Software - Telecom Software',
#          'IT Software - Embedded', 'IT Software - Middleware', 'Teaching',
#          'IT Software - System Programming',
#          'IT Software - Client/Server Programming', 'Travel',
#          'IT Software - eCommerce', 'TV', 'Fashion Designing',
#          'IT Software - ERP', 'IT Hardware',
#          'Analytics & Business Intelligence', 'Beauty/Fitness/Spa Services',
#          'Top Management', 'Export', 'IT Software - Systems', 'Packaging',
#          'Shipping'], dtype=object)],
#  ['uniq_id',
#   22000,
#   array(['43b19632647068535437c774b6ca6cf8',
#          'd4c72325e57f89f364812b5ed5a795f0',
#          'c47df6f4cfdf5b46f1fd713ba61b9eba', ...,
#          'f6f2885a6c87572616fb766029a0d284',
#          'c6f6538cb1007dd02c1b4b77909b3d38',
#          '74fec26df6e1c0be0171311a2f03f180'], dtype=object)]]

# %%
count_df=pd.DataFrame(unique_df, columns=['col_name','count','unique'])
count_df
# Out:
#                col_name  count  \
# 0               company   8469
# 1             education   2355
# 2            experience    147
# 3              industry     63
# 4        jobdescription  21063
# 5                 jobid  21910
# 6   joblocation_address   2329
# 7              jobtitle  17564
# 8     numberofpositions     84
# 9               payrate   1848
# 10             postdate   4203
# 11            site_name      1
# 12               skills     45
# 13              uniq_id  22000
#
#                                                unique
# 0   [MM Media Pvt Ltd, find live infotech, Softtec...
# 1   [UG: B.Tech/B.E. - Any Specialization PG:Any P...
# 2   [0 - 1 yrs, 0 - 0 yrs, 4 - 8 yrs, 11 - 15 yrs,...
# 3   [Media / Entertainment / Internet, Advertising...
# 4   [Job Description   Send me Jobs like this Qual...
# 5   [210516002263, 210516002391, 101016900534, 810...
# 6   [Chennai, Bengaluru, Mumbai, Bengaluru, Kolkat...
# 7   [Walkin Data Entry Operator (night Shift), Wor...
# 8   [nan, 60.0, 4.0, 2.0, 20.0, 3.0, 1.0, 700.0, 8...
# 9   [1,50,000 - 2,25,000 P.A, 1,50,000 - 2,50,000 ...
# 10  [2016-05-21 19:30:00 +0000, 2016-10-13 16:20:5...
# 11                              [nan, www.naukri.com]
# 12  [ITES, Marketing, IT Software - Application Pr...
# 13  [43b19632647068535437c774b6ca6cf8, d4c72325e57...

# %%
count_df.style.background_gradient()
# Out:
# <style type="text/css">
# #T_7f804_row0_col1 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_7f804_row1_col1, #T_7f804_row6_col1 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_7f804_row2_col1 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_7f804_row3_col1, #T_7f804_row8_col1, #T_7f804_row11_col1, #T_7f804_row12_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_7f804_row4_col1 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_7f804_row5_col1 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_7f804_row7_col1 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_7f804_row9_col1 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_7f804_row10_col1 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_7f804_row13_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7f804">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7f804_level0_col0" class="col_heading level0 col0" >col_name</th>
#       <th id="T_7f804_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_7f804_level0_col2" class="col_heading level0 col2" >unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f804_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7f804_row0_col0" class="data row0 col0" >company</td>
#       <td id="T_7f804_row0_col1" class="data row0 col1" >8469</td>
#       <td id="T_7f804_row0_col2" class="data row0 col2" >['MM Media Pvt Ltd' 'find live infotech'
#  'Softtech Career Infosystem Pvt. Ltd' ...
#  'TeamLease Services Limited hiring for BPA Solution Architect'
#  'Austere Technology Solutions' 'Musk - Startup']</td>
#     </tr>
#     <tr>
#       <th id="T_7f804_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7f804_row1_col0" class="data row1 col0" >education</td>
#       <td id="T_7f804_row1_col1" class="data row1 col1" >2355</td>
#       <td id="T_7f804_row1_col2" class="data row1 col2" >['UG: B.Tech/B.E. - Any Specialization PG:Any Postgraduate - Any Specialization, Post Graduation Not Required'
#  'UG: B.Tech/B.E. - Any Specialization PG:MBA/PGDM - Any Specialization'
#  'UG: Any Graduate - Any Specialization PG:Any Postgraduate Doctorate:Doctorate Not Required'
#  ... 'PG:MS/M.Sc(Science) - Any Specialization, Statistics'
#  'UG: B.Tech/B.E. - Any Specialization PG:MCA - Computers, M.Tech - Any Specialization, MS/M.Sc(Science) - Any Specialization Doctorate:Doctorate Not Required'
#  'UG: B.Tech/B.E. - Computers PG:MS/M.Sc(Science) - Computers Doctorate:Doctorate Not Required']</td>
#     </tr>
#     <tr>
#       <th id="T_7f804_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7f804_row2_col0" class="data row2 col0" >experience</td>
#       <td id="T_7f804_row2_col1" class="data row2 col1" >147</td>
#       <td id="T_7f804_row2_col2" class="data row2 col2" >['0 - 1 yrs' '0 - 0 yrs' '4 - 8 yrs' '11 - 15 yrs' '6 - 8 yrs' '2 - 5 yrs'
#  '1 - 3 yrs' '2 - 7 yrs' '1 - 5 yrs' '2 - 4 yrs' '3 - 8 yrs' '5 - 7 yrs'
#  '1 - 2 yrs' '5 - 10 yrs' '6 - 10 yrs' '10 - 12 yrs' '4 - 6 yrs'
#  '1 - 6 yrs' '3 - 6 yrs' '3 - 7 yrs' '4 - 9 yrs' '3 - 5 yrs' '0 - 5 yrs'
#  '5 - 8 yrs' '9 - 12 yrs' '7 - 12 yrs' '10 - 15 yrs' '4 - 7 yrs'
#  '8 - 12 yrs' '10 - 16 yrs' '5 - 9 yrs' '0 - 4 yrs' '10 - 20 yrs'
#  '10 - 18 yrs' '0 - 2 yrs' '7 - 10 yrs' '6 - 11 yrs' '2 - 3 yrs'
#  '1 - 4 yrs' '7 - 9 yrs' '8 - 13 yrs' '2 - 6 yrs' '8 - 10 yrs' '0 - 3 yrs'
#  '6 - 9 yrs' '15 - 20 yrs' '12 - 16 yrs' '1 - 1 yrs' '3 - 4 yrs'
#  '17 - 20 yrs' '10 - 17 yrs' '9 - 14 yrs' '13 - 15 yrs' '17 - 23 yrs'
#  '15 - 25 yrs' '14 - 22 yrs' '4 - 5 yrs' '7 - 11 yrs' '16 - 24 yrs'
#  '14 - 18 yrs' '12 - 15 yrs' '7 - 8 yrs' '5 - 6 yrs' '12 - 19 yrs'
#  '20 - 25 yrs' '10 - 13 yrs' '12 - 18 yrs' '6 - 7 yrs' '10 - 14 yrs'
#  '12 - 20 yrs' 'Not Mentioned' '11 - 16 yrs' '15 - 17 yrs' '20 - 30 yrs'
#  '15 - 21 yrs' '8 - 11 yrs' '8 - 9 yrs' '9 - 13 yrs' '15 - 22 yrs'
#  '14 - 19 yrs' '13 - 19 yrs' '15 - 16 yrs' '14 - 20 yrs' '11 - 12 yrs'
#  '1 - 8 yrs' '9 - 11 yrs' '15 - 18 yrs' '4 - 10 yrs' '10 - 11 yrs'
#  '12 - 22 yrs' '7 - 16 yrs' '16 - 18 yrs' '13 - 17 yrs' '13 - 20 yrs'
#  '5 - 5 yrs' '1 - 10 yrs' '12 - 14 yrs' '5 - 15 yrs' '11 - 17 yrs' nan
#  '16 - 20 yrs' '13 - 23 yrs' '3 - 3 yrs' '18 - 20 yrs' '23 - 30 yrs'
#  '14 - 24 yrs' '18 - 28 yrs' '11 - 21 yrs' '15 - 19 yrs' '18 - 22 yrs'
#  '6 - 12 yrs' '14 - 17 yrs' '12 - 17 yrs' '13 - 18 yrs' '25 - 30 yrs'
#  '11 - 14 yrs' '2 - 8 yrs' '2 - 10 yrs' '4 - 11 yrs' '11 - 13 yrs'
#  '14 - 16 yrs' '2 - 2 yrs' '10 - 19 yrs' '14 - 15 yrs' '2 - 9 yrs'
#  '13 - 16 yrs' '7 - 7 yrs' '9 - 10 yrs' '11 - 20 yrs' '12 - 13 yrs'
#  '15 - 24 yrs' '3 - -1 yrs' '10 - 10 yrs' '26 - 30 yrs' '7 - 14 yrs'
#  '11 - 19 yrs' '16 - 25 yrs' '11 - 18 yrs' '18 - 25 yrs' '17 - 25 yrs'
#  '18 - 21 yrs' '18 - 23 yrs' '20 - 24 yrs' '20 - 23 yrs' '3 - 10 yrs'
#  '17 - 27 yrs' '16 - 26 yrs' '13 - 22 yrs']</td>
#     </tr>
#     <tr>
#       <th id="T_7f804_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7f804_row3_col0" class="data row3 col0" >industry</td>
#       <td id="T_7f804_row3_col1" class="data row3 col1" >63</td>
#       <td id="T_7f804_row3_col2" class="data row3 col2" >['Media / Entertainment / Internet'
#  'Advertising / PR / MR / Event Management'
#  'IT-Software / Software Services'
#  'Banking / Financial Services / Broking' 'Aviation / Aerospace Firms'
#  'Industrial Products / Heavy Machinery' 'FMCG / Foods / Beverage'
#  'Recruitment / Staffing' 'Internet / Ecommerce'
#  'Travel / Hotels / Restaurants / Airlines / Railways'
#  'BPO / Call Centre / ITES' 'Pharma / Biotech / Clinical Research'
#  'Real Estate / Property' 'Insurance' 'Facility Management' 'Publishing'
#  'Education / Teaching / Training' 'Retail / Wholesale'
#  'Automobile / Auto Anciliary / Auto Components'
#  'Chemicals / PetroChemical / Plastic / Rubber' 'Government / Defence'
#  'Accounting / Finance' 'Textiles / Garments / Accessories'
#  'Semiconductors / Electronics' 'Telecom/ISP'
#  'Medical / Healthcare / Hospitals' 'Legal'
#  'Courier / Transportation / Freight / Warehousing'
#  'NGO / Social Services / Regulators / Industry Associations' 'Other'
#  'Architecture / Interior Design' 'KPO / Research / Analytics'
#  'Construction / Engineering / Cement / Metals'
#  'Office Equipment / Automation'
#  'Consumer Electronics / Appliances / Durables' 'Iron and Steel'
#  'Strategy / Management Consulting Firms'
#  'Oil and Gas / Energy / Power / Infrastructure'
#  'IT-Hardware & Networking' 'Wellness / Fitness / Sports / Beauty'
#  'Agriculture / Dairy' 'Electricals / Switchgears'
#  'Security / Law Enforcement' 'Gems / Jewellery'
#  'Ceramics / Sanitary ware' 'Fresher / Trainee / Entry Level'
#  'Food Processing' 'Printing / Packaging' 'Brewery / Distillery'
#  'Telecom/ISP /' 'Export / Import' 'Heat Ventilation / Air Conditioning'
#  'Wellness / Fitness / Sports' 'Water Treatment / Waste Management' nan
#  'Shipping / Marine' 'Glass / Glassware' 'Animation / Gaming'
#  'Fertilizers / Pesticides' 'Pulp and Paper' 'Tyres' 'Leather'
#  'Broadcasting' 'Medical Devices / Equipments']</td>
#     </tr>
#     <tr>
#       <th id="T_7f804_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7f804_row4_col0" class="data row4 col0" >jobdescription</td>
#       <td id="T_7f804_row4_col1" class="data row4 col1" >21063</td>
#       <td id="T_7f804_row4_col2" class="data row4 col2" >['Job Description \xa0 Send me Jobs like this Qualifications: - == > 10th To Graduation & Any Skill: - == > Basic Computer Knowledge Job Requirement : - == > System or Laptop Type of job: - == > Full Time or Part time Languages : - == > Tamil & English. Experience : - == > Freshers & Experience payment details: - 1 form per day 5/- 10 form per day 50/- 100 form per day 500/- monthly you can earn 15000/- per month Selection Process: - == > Easy Selection Process,So What Are You Waiting For? Apply Now & Grab Best Opportunity To Make Your Carrier & To Improve Your Earing Skills. More detail contact Mr Hari 8678902528 9003010282 Salary:INR 1,50,000 - 2,25,000 P.A Industry: Media / Entertainment / Internet Functional Area: ITES ,

# %% [markdown]
# ## Now we will do feature engineering on Payrate column to get minimum and maximum numeric values
#
# - Currently PayRate feature has a single text value which consits of both minimum and maximum value
# - Our aim is to create 2 numeric columns using this column which would contain miminum value and maximum value

# %%
# We will first look into the type of values flowing in the column

df['payrate'].head(20)
# Out:
# 0                               1,50,000 - 2,25,000 P.A
# 1                        1,50,000 - 2,50,000 P.A. 20000
# 2                            Not Disclosed by Recruiter
# 3                            Not Disclosed by Recruiter
# 4                            Not Disclosed by Recruiter
# 5                            Not Disclosed by Recruiter
# 6                               3,00,000 - 6,50,000 P.A
# 7                            Not Disclosed by Recruiter
# 8                               1,00,000 - 2,00,000 P.A
# 9                            Not Disclosed by Recruiter
# 10                           Not Disclosed by Recruiter
# 11                           Not Disclosed by Recruiter
# 12                              1,75,000 - 2,50,000 P.A
# 13                           Not Disclosed by Recruiter
# 14                           Not Disclosed by Recruiter
# 15                           Not Disclosed by Recruiter
# 16    1,00,000 - 2,00,000 P.A. incentives for achiev...
# 17                              1,00,000 - 5,00,000 P.A
# 18                           Not Disclosed by Recruiter
# 19                           Not Disclosed by Recruiter
# Name: payrate, dtype: object

# %% [markdown]
# - Looking at above our first approach would be to split on basis of "-" and get both the values

# %%
df['payrate'][0].split('-')
# Out:
# ['1,50,000 ', ' 2,25,000 P.A']

# %%
df['payrate'][0].split('-')[0]
# Out:
# '1,50,000 '

# %%
df['payrate'][0].split('-')[1]
# Out:
# ' 2,25,000 P.A'

# %%
# If we split the values based on "-" then we see some records with more than 2 partitions
# So, ths=is approach would not work for all the records

len_pay=[]
for pay in df['payrate']:
    len_pay.append(len(str(pay).split('-')))

pd.Series(len_pay).value_counts()
# Out:
# 1    17028
# 2     4682
# 4      126
# 3       83
# 5       54
# 6       24
# 7        3
# dtype: int64

# %%
# Our next approach is to convert the values in a dataframe 

payrate_split=df['payrate'].str.split('-')
payrate_split
# Out:
# 0               [1,50,000 ,  2,25,000 P.A]
# 1        [1,50,000 ,  2,50,000 P.A. 20000]
# 2             [Not Disclosed by Recruiter]
# 3             [Not Disclosed by Recruiter]
# 4             [Not Disclosed by Recruiter]
#                        ...
# 21995         [Not Disclosed by Recruiter]
# 21996          [8,50,000 ,  14,00,000 P.A]
# 21997         [Not Disclosed by Recruiter]
# 21998         [Not Disclosed by Recruiter]
# 21999         [12,00,000 ,  22,00,000 P.A]
# Name: payrate, Length: 22000, dtype: object

# %%
# Using expand we have have each value in a specific columns
# Now we can only use column 0 and 1 and disregard others

payrate_split=df['payrate'].str.split('-', expand=True)
payrate_split
# Out:
#                                 0                     1     2     3     4  \
# 0                       1,50,000           2,25,000 P.A  None  None  None
# 1                       1,50,000    2,50,000 P.A. 20000  None  None  None
# 2      Not Disclosed by Recruiter                  None  None  None  None
# 3      Not Disclosed by Recruiter                  None  None  None  None
# 4      Not Disclosed by Recruiter                  None  None  None  None
# ...                           ...                   ...   ...   ...   ...
# 21995  Not Disclosed by Recruiter                  None  None  None  None
# 21996                   8,50,000          14,00,000 P.A  None  None  None
# 21997  Not Disclosed by Recruiter                  None  None  None  None
# 21998  Not Disclosed by Recruiter                  None  None  None  None
# 21999                  12,00,000          22,00,000 P.A  None  None  None
#
#           5     6
# 0      None  None
# 1      None  None
# 2      None  None
# 3      None  None
# 4      None  None
# ...     ...   ...
# 21995  None  None
# 21996  None  None
# 21997  None  None
# 21998  None  None
# 21999  None  None
#
# [22000 rows x 7 columns]

# %% [markdown]
# #### Now we will clean up the minimum value column of Pay Rate
# ##### To perform this we need to do 4 basic steps:
# - 1. Remove any extra spaces from the value
# - 2. Remove commas from the values
# - 3. Remove any set of characters available
# - 4. Convert object type to float type/ int type

# %%
# to remove extra spaces from the values we will use strip() function

payrate_split[0]=payrate_split[0].str.strip()
payrate_split[0]
# Out:
# 0                          1,50,000
# 1                          1,50,000
# 2        Not Disclosed by Recruiter
# 3        Not Disclosed by Recruiter
# 4        Not Disclosed by Recruiter
#                     ...
# 21995    Not Disclosed by Recruiter
# 21996                      8,50,000
# 21997    Not Disclosed by Recruiter
# 21998    Not Disclosed by Recruiter
# 21999                     12,00,000
# Name: 0, Length: 22000, dtype: object

# %%
# Now we will replace all commas using replace() function

payrate_split[0].str.replace(',','')
# Out:
# 0                            150000
# 1                            150000
# 2        Not Disclosed by Recruiter
# 3        Not Disclosed by Recruiter
# 4        Not Disclosed by Recruiter
#                     ...
# 21995    Not Disclosed by Recruiter
# 21996                        850000
# 21997    Not Disclosed by Recruiter
# 21998    Not Disclosed by Recruiter
# 21999                       1200000
# Name: 0, Length: 22000, dtype: object

# %%
# We can also use lambda function to replace all the commas

payrate_split[0]=payrate_split[0].apply(lambda x:str(x).replace(',',''))
payrate_split[0]
# Out:
# 0                            150000
# 1                            150000
# 2        Not Disclosed by Recruiter
# 3        Not Disclosed by Recruiter
# 4        Not Disclosed by Recruiter
#                     ...
# 21995    Not Disclosed by Recruiter
# 21996                        850000
# 21997    Not Disclosed by Recruiter
# 21998    Not Disclosed by Recruiter
# 21999                       1200000
# Name: 0, Length: 22000, dtype: object

# %% [markdown]
# - Now to remove any characters we have in our feature we have 3 options:
#  1. We can use exceptional handling to assign any default value to all the character values
#  2. We can use to_numeric function
#  3. We can use regular expressions

# %%
# We would first try using exceptional handling

pay=[]
for payrate in payrate_split[0]:
    try:
        if type(float(payrate))==np.float:
            pay.append(payrate)
    except:
            pay.append('missing value')

pay
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8580\1866450789.py:6: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if type(float(payrate))==np.float:
# ['150000',
#  '150000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '300000',
#  'missing value',
#  '100000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '175000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '100000',
#  '100000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '150000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '175000',
#  '50000',
#  '900000',
#  'missing value',
#  'missing value',
#  '500000',
#  'missing value',
#  'missing value',
#  '400000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '400000',
#  '250000',
#  'missing value',
#  '300000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '50000',
#  'missing value',
#  '700000',
#  'missing value',
#  '600000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '125000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '150000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '300000',
#  'missing value',
#  '150000',
#  'missing value',
#  '100000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '800000',
#  '225000',
#  'missing value',
#  '300000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '100000',
#  '200000',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  '300000',
#  'missing value',
#  'missing value',
#  '150000',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  '150000',
#  'missing value',
#  '1200000',
#  '200000',
#  '500000',
#  '150000',
#  'missing value',
#  '300000',
#  'missing value',
#  '600000',
#  '250000',
#  'missing value',
#  '425000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '100000',
#  'missing value',
#  '500000',
#  'missing value',
#  '300000',
#  'missing value',
#  '150000',
#  'missing value',
#  'missing value',
#  '1400000',
#  '200000',
#  '100000',
#  '400000',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '150000',
#  '225000',
#  '500000',
#  'missing value',
#  'missing value',
#  '400000',
#  'missing value',
#  'missing value',
#  '175000',
#  '300000',
#  '200000',
#  '200000',
#  'missing value',
#  '700000',
#  '650000',
#  'missing value',
#  'missing value',
#  '500000',
#  'missing value',
#  '175000',
#  '600000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '175000',
#  '200000',
#  '200000',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  '50000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '200000',
#  '150000',
#  '200000',
#  'missing value',
#  '175000',
#  '700000',
#  '500000',
#  '600000',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '200000',
#  '125000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '150000',
#  '300000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '175000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '150000',
#  '500000',
#  '1000000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '650000',
#  '300000',
#  'missing value',
#  'missing value',
#  '400000',
#  'missing value',
#  '650000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '50000',
#  'missing value',
#  '600000',
#  'missing value',
#  '500000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  '300000',
#  'missing value',
#  '175000',
#  '225000',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  '1200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '225000',
#  'missing value',
#  'missing value',
#  '65000',
#  'missing value',
#  '175000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '150000',
#  '750000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '3000000',
#  'missing value',
#  '600000',
#  '300000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '400000',
#  'missing value',
#  'missing value',
#  '350000',
#  '300000',
#  '400000',
#  '200000',
#  '550000',
#  'missing value',
#  '200000',
#  'missing value',
#  '200000',
#  '800000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '100000',
#  'missing value',
#  '100000',
#  '200000',
#  '175000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '225000',
#  'missing value',
#  '250000',
#  'missing value',
#  '400000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '100000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '175000',
#  'missing value',
#  'missing value',
#  '50000',
#  'missing value',
#  '300000',
#  '2000000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '300000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '450000',
#  '175000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '80000',
#  '300000',
#  'missing value',
#  '600000',
#  '350000',
#  'missing value',
#  'missing value',
#  '600000',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '325000',
#  'missing value',
#  'missing value',
#  '150000',
#  '400000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '1500000',
#  'missing value',
#  '100000',
#  'missing value',
#  '2000000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '1200000',
#  'missing value',
#  'missing value',
#  '225000',
#  'missing value',
#  '175000',
#  'missing value',
#  '150000',
#  '500000',
#  'missing value',
#  '200000',
#  '1000000',
#  'missing value',
#  '350000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '200000',
#  '125000',
#  '50000',
#  'missing value',
#  '125000',
#  '350000',
#  'missing value',
#  '375000',
#  '350000',
#  'missing value',
#  '200000',
#  '175000',
#  '550000',
#  'missing value',
#  'missing value',
#  '225000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '500000',
#  'missing value',
#  '500000',
#  'missing value',
#  '325000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '200000',
#  '300000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '150000',
#  '325000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '2000000',
#  '200000',
#  'missing value',
#  '600000',
#  '3500000',
#  '300000',
#  '300000',
#  'missing value',
#  '1000000',
#  'missing value',
#  'missing value',
#  '200000',
#  '300000',
#  'missing value',
#  '100000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '500000',
#  'missing value',
#  '600000',
#  '450000',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  '2000000',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  '50000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '300000',
#  '200000',
#  'missing value',
#  '125000',
#  'missing value',
#  '325000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '50000',
#  '175000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '175000',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  '200000',
#  '600000',
#  'missing value',
#  '175000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '50000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '300000',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '60000',
#  '175000',
#  '200000',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '900000',
#  'missing value',
#  '90000',
#  '1100000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '200000',
#  '150000',
#  '175000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '400000',
#  '300000',
#  '1000000',
#  'missing value',
#  '800000',
#  'missing value',
#  '150000',
#  'missing value',
#  '200000',
#  'missing value',
#  '2000000',
#  'missing value',
#  'missing value',
#  '700000',
#  'missing value',
#  '100000',
#  '125000',
#  '200000',
#  'missing value',
#  '2000000',
#  '200000',
#  '300000',
#  '600000',
#  'missing value',
#  '200000',
#  'missing value',
#  '200000',
#  'missing value',
#  '125000',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '2000000',
#  '200000',
#  'missing value',
#  '200000',
#  '225000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '175000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '80000',
#  '2000000',
#  'missing value',
#  '300000',
#  '2000000',
#  'missing value',
#  '50000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '100000',
#  '700000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '50000',
#  '900000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '400000',
#  '200000',
#  '300000',
#  'missing value',
#  '275000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '400000',
#  'missing value',
#  '500000',
#  '50000',
#  'missing value',
#  'missing value',
#  '300000',
#  'missing value',
#  '350000',
#  '300000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '100000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '300000',
#  'missing value',
#  'missing value',
#  '200000',
#  '100000',
#  'missing value',
#  '300000',
#  'missing value',
#  '175000',
#  '400000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '200000',
#  '100000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '300000',
#  'missing value',
#  '325000',
#  'missing value',
#  '50000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '50000',
#  'missing value',
#  'missing value',
#  '600000',
#  'missing value',
#  '500000',
#  'missing value',
#  '1300000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '800000',
#  'missing value',
#  '300000',
#  '600000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '450000',
#  'missing value',
#  'missing value',
#  '200000',
#  '300000',
#  'missing value',
#  '300000',
#  '200000',
#  '400000',
#  'missing value',
#  '275000',
#  '275000',
#  'missing value',
#  '900000',
#  'missing value',
#  '300000',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '150000',
#  '200000',
#  '300000',
#  '700000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '200000',
#  '700000',
#  '500000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '800000',
#  'missing value',
#  'missing value',
#  '200000',
#  '275000',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '175000',
#  '400000',
#  'missing value',
#  '200000',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '50000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '900000',
#  'missing value',
#  '150000',
#  '400000',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '225000',
#  'missing value',
#  '2000000',
#  'missing value',
#  'missing value',
#  '175000',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  '500000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  '300000',
#  'missing value',
#  'missing value',
#  '250000',
#  'missing value',
#  '275000',
#  'missing value',
#  'missing value',
#  '175000',
#  'missing value',
#  '100000',
#  '600000',
#  '400000',
#  'missing value',
#  'missing value',
#  '350000',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  '300000',
#  'missing value',
#  '300000',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '450000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '1000000',
#  '700000',
#  '200000',
#  '450000',
#  'missing value',
#  '325000',
#  '300000',
#  '500000',
#  '250000',
#  '175000',
#  'missing value',
#  '125000',
#  '200000',
#  'missing value',
#  'missing value',
#  '100000',
#  'missing value',
#  'missing value',
#  '200000',
#  '300000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '300000',
#  '125000',
#  'missing value',
#  '100000',
#  '200000',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '100000',
#  'missing value',
#  '175000',
#  '175000',
#  '750000',
#  'missing value',
#  'missing value',
#  '700000',
#  '225000',
#  'missing value',
#  'missing value',
#  '200000',
#  '1600000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  '150000',
#  '225000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '50000',
#  'missing value',
#  '400000',
#  '150000',
#  'missing value',
#  '50000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '225000',
#  '300000',
#  '250000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '325000',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '100000',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  '700000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '400000',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '275000',
#  'missing value',
#  '300000',
#  '400000',
#  '275000',
#  '225000',
#  'missing value',
#  '200000',
#  'missing value',
#  '2000000',
#  '225000',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '100000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '250000',
#  '1200000',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '400000',
#  'missing value',
#  ...]

# %%
# Here we are using to_numeric function
# errors='coerce' will set invalid parsing as NaN
# errors='raise' will raise an exception
# errors='ignore' will return the input

pd.to_numeric(payrate_split[0],errors='coerce')
# Out:
# 0         150000.0
# 1         150000.0
# 2              NaN
# 3              NaN
# 4              NaN
#            ...
# 21995          NaN
# 21996     850000.0
# 21997          NaN
# 21998          NaN
# 21999    1200000.0
# Name: 0, Length: 22000, dtype: float64

# %%
# Here we are using regular expression to find the character pattern and replace it

pattern='\D.*'
payrate_split[0].str.replace(pattern,'')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8580\1901366369.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   payrate_split[0].str.replace(pattern,'')
# 0         150000
# 1         150000
# 2
# 3
# 4
#           ...
# 21995
# 21996     850000
# 21997
# 21998
# 21999    1200000
# Name: 0, Length: 22000, dtype: object

# %% [markdown]
# - Any Map function can be used to check the data type

# %%
any(map(str.isdigit,payrate_split[0]))
# Out:
# True

# %%
any(map(str.isnumeric,payrate_split[0]))
# Out:
# True

# %% [markdown]
# #### In Previous steps we tried to clean up the minimum value of Pay Rate, now lets clean maximum value of Pay Rate.
# ##### To perform this we need to do 4 basic steps:
# - 1. Remove any extra spaces from the value
# - 2. Remove commas from the values
# - 3. Remove any set of characters available
# - 4. Convert object type to float type/ int type

# %%
payrate_split[1][0]
# Out:
# ' 2,25,000 P.A'

# %%
# Remove extra spaces using strip function

payrate_split[1]=payrate_split[1].str.strip()
payrate_split[1]
# Out:
# 0               2,25,000 P.A
# 1        2,50,000 P.A. 20000
# 2                       None
# 3                       None
# 4                       None
#                 ...
# 21995                   None
# 21996          14,00,000 P.A
# 21997                   None
# 21998                   None
# 21999          22,00,000 P.A
# Name: 1, Length: 22000, dtype: object

# %%
# Remove comma from the values using lambda replace function

payrate_split[1]=payrate_split[1].apply(lambda x:str(x).replace(',',''))
payrate_split[1]
# Out:
# 0               225000 P.A
# 1        250000 P.A. 20000
# 2                     None
# 3                     None
# 4                     None
#                ...
# 21995                 None
# 21996          1400000 P.A
# 21997                 None
# 21998                 None
# 21999          2200000 P.A
# Name: 1, Length: 22000, dtype: object

# %%
# Remove set of characters using regular expression function

pattern='\D.*'
payrate_split[1]=payrate_split[1].str.replace(pattern,'')
payrate_split[1]
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8580\2447838714.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   payrate_split[1]=payrate_split[1].str.replace(pattern,'')
# 0         225000
# 1         250000
# 2
# 3
# 4
#           ...
# 21995
# 21996    1400000
# 21997
# 21998
# 21999    2200000
# Name: 1, Length: 22000, dtype: object

# %%
# We will now check the data type of the minimum and maximum values of payrate

payrate_split.dtypes
# Out:
# 0    object
# 1    object
# 2    object
# 3    object
# 4    object
# 5    object
# 6    object
# dtype: object

# %%
# As we can see 0 and 1 have object data type which we need to convert to numeric data type. 
# We will use to_numeric function of pandas to perform this

payrate_split[0]=pd.to_numeric(payrate_split[0], errors='coerce')
payrate_split[1]=pd.to_numeric(payrate_split[1], errors='coerce')

payrate_split.dtypes
# Out:
# 0    float64
# 1    float64
# 2     object
# 3     object
# 4     object
# 5     object
# 6     object
# dtype: object

# %% [markdown]
# #### We need to now add mimimum and maximum payrate values in our dataframe. We have 2 approaches for this:
# #### 1. We can use concat function of pandas to perform this
# #### 2. We can create new feauture column and assign payrate_split[0] or [1] into this
#
# ##### To be noted that if we have a lot of new features in that case if would be very difficult and time taking to follow approach 2 and hence approach 1 is suggested as we do not want to write steps for all 20-30 new features

# %%
# Lets try to use the 2nd approach first and see the results

df['min_pay']=payrate_split[0]
df['max_pay']=payrate_split[1]

df.head(10)
# Out:
#                                              company  \
# 0                                   MM Media Pvt Ltd
# 1                                 find live infotech
# 2                Softtech Career Infosystem Pvt. Ltd
# 3                             Onboard HRServices LLP
# 4         Spire Technologies and Solutions Pvt. Ltd.
# 5                    PFS Web Global Services Pvt Ltd
# 6             Kinesis Management Consultant Pvt. Ltd
# 7  Agile HR consultancy Pvt. Ltd. hiring for Ross...
# 8                  HANSUM INDIA ELECTRONICS PVT.LTD.
# 9                                          Accenture
#
#                                            education   experience  \
# 0  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    0 - 1 yrs
# 1  UG: B.Tech/B.E. - Any Specialization PG:MBA/PG...    0 - 0 yrs
# 2  UG: Any Graduate - Any Specialization PG:Any P...    4 - 8 yrs
# 3  UG: Any Graduate - Any Specialization PG:CA Do...  11 - 15 yrs
# 4  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    6 - 8 yrs
# 5  UG: B.Tech/B.E. - Any Specialization PG:MCA - ...    2 - 5 yrs
# 6                                                NaN    1 - 3 yrs
# 7  UG: Diploma - Any Specialization, Electrical, ...    2 - 7 yrs
# 8  UG: Diploma - Any Specialization, Electronics/...    1 - 3 yrs
# 9  UG: Any Graduate - Any Specialization PG:Any P...    1 - 5 yrs
#
#                                    industry  \
# 0          Media / Entertainment / Internet
# 1  Advertising / PR / MR / Event Management
# 2           IT-Software / Software Services
# 3    Banking / Financial Services / Broking
# 4           IT-Software / Software Services
# 5           IT-Software / Software Services
# 6           IT-Software / Software Services
# 7                Aviation / Aerospace Firms
# 8     Industrial Products / Heavy Machinery
# 9           IT-Software / Software Services
#
#                                       jobdescription         jobid  \
# 0  Job Description   Send me Jobs like this Quali...  210516002263
# 1  Job Description   Send me Jobs like this Quali...  210516002391
# 2  Job Description   Send me Jobs like this - as ...  101016900534
# 3  Job Description   Send me Jobs like this - Inv...   81016900536
# 4  Job Description   Send me Jobs like this Pleas...  120916002122
# 5  Job Description   Send me Jobs like this We ar...  131016005070
# 6  Job Description   Send me Jobs like this exper...  131016004451
# 7  Job Description   Send me Jobs like this Job D...  121016002995
# 8  Job Description   Send me Jobs like this Indep...  131016002120
# 9  Job Description   Send me Jobs like this Overa...  121016901354
#
#                                  joblocation_address  \
# 0                                            Chennai
# 1                                            Chennai
# 2                                          Bengaluru
# 3  Mumbai, Bengaluru, Kolkata, Chennai, Coimbator...
# 4                                          Bengaluru
# 5                                          Bengaluru
# 6  Delhi NCR, Mumbai, Bengaluru, Kochi, Greater N...
# 7                                          Bengaluru
# 8                                          Bengaluru
# 9                                          Bengaluru
#
#                                             jobtitle  numberofpositions  \
# 0           Walkin Data Entry Operator (night Shift)                NaN
# 1                 Work Based Onhome Based Part Time.               60.0
# 2                             Pl/sql Developer - SQL                NaN
# 3             Manager/ad/partner - Indirect Tax - CA                NaN
# 4                    JAVA Technical Lead (6-8 yrs) -                4.0
# 5  WALK IN - As400 Developer - Pfsweb Global Serv...                NaN
# 6                                      PHP Developer                2.0
# 7  Member Technical Staff-wire Harness/cable Harn...               20.0
# 8                                        Team Leader                2.0
# 9                                  German Translator                NaN
#
#                           payrate                   postdate site_name  \
# 0         1,50,000 - 2,25,000 P.A  2016-05-21 19:30:00 +0000       NaN
# 1  1,50,000 - 2,50,000 P.A. 20000  2016-05-21 19:30:00 +0000       NaN
# 2      Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000       NaN
# 3      Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000       NaN
# 4      Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000       NaN
# 5      Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000       NaN
# 6         3,00,000 - 6,50,000 P.A  2016-10-13 16:20:55 +0000       NaN
# 7      Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000       NaN
# 8         1,00,000 - 2,00,000 P.A  2016-10-13 16:20:55 +0000       NaN
# 9      Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000       NaN
#
#                                   skills                           uniq_id  \
# 0                                   ITES  43b19632647068535437c774b6ca6cf8
# 1                              Marketing  d4c72325e57f89f364812b5ed5a795f0
# 2  IT Software - Application Programming  c47df6f4cfdf5b46f1fd713ba61b9eba
# 3                               Accounts  115d28f140f694dd1cc61c53d03c66ae
# 4  IT Software - Application Programming  a12553fc03bc7bcced8b1bb8963f97b4
# 5  IT Software - Application Programming  8c3af9062ea835b0965779e2c7faac76
# 6  IT Software - Application Programming  98f84958cd6409386e7f0c9e447b8510
# 7                             Production  c811c10568fdbfdb3d5e633c99c914b4
# 8                             Production  a40cb270401af0c246dbe60dcf219262
# 9                                   ITES  7774df1c672c0b92486da8b36a721638
#
#    min_exp  max_exp  avg_exp   min_pay   max_pay
# 0      0.0      1.0      0.5  150000.0  225000.0
# 1      0.0      0.0      0.0  150000.0  250000.0
# 2      4.0      8.0      6.0       NaN       NaN
# 3     11.0     15.0     13.0       NaN       NaN
# 4      6.0      8.0      7.0       NaN       NaN
# 5      2.0      5.0      3.5       NaN       NaN
# 6      1.0      3.0      2.0  300000.0  650000.0
# 7      2.0      7.0      4.5       NaN       NaN
# 8      1.0      3.0      2.0  100000.0  200000.0
# 9      1.0      5.0      3.0       NaN       NaN

# %%
# Here we will use concat function to add the columns

pay=pd.concat([payrate_split[0],payrate_split[1]], axis=1, sort=False)
pay.columns=['min_pay','max_pay']
pay
# Out:
#          min_pay    max_pay
# 0       150000.0   225000.0
# 1       150000.0   250000.0
# 2            NaN        NaN
# 3            NaN        NaN
# 4            NaN        NaN
# ...          ...        ...
# 21995        NaN        NaN
# 21996   850000.0  1400000.0
# 21997        NaN        NaN
# 21998        NaN        NaN
# 21999  1200000.0  2200000.0
#
# [22000 rows x 2 columns]

# %%
# Let's rename min_pay and max_pay already existing in the dataframe to min_pay_2 and max_pay_2 to indicate created  
# using 2nd approach

df.rename(columns={"min_pay":"min_pay_2", "max_pay":"max_pay_2"}, inplace=True)

# %%
df=pd.concat([df,pay],axis=1, sort=False)

# %%
df.head(6)
# Out:
#                                       company  \
# 0                            MM Media Pvt Ltd
# 1                          find live infotech
# 2         Softtech Career Infosystem Pvt. Ltd
# 3                      Onboard HRServices LLP
# 4  Spire Technologies and Solutions Pvt. Ltd.
# 5             PFS Web Global Services Pvt Ltd
#
#                                            education   experience  \
# 0  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    0 - 1 yrs
# 1  UG: B.Tech/B.E. - Any Specialization PG:MBA/PG...    0 - 0 yrs
# 2  UG: Any Graduate - Any Specialization PG:Any P...    4 - 8 yrs
# 3  UG: Any Graduate - Any Specialization PG:CA Do...  11 - 15 yrs
# 4  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    6 - 8 yrs
# 5  UG: B.Tech/B.E. - Any Specialization PG:MCA - ...    2 - 5 yrs
#
#                                    industry  \
# 0          Media / Entertainment / Internet
# 1  Advertising / PR / MR / Event Management
# 2           IT-Software / Software Services
# 3    Banking / Financial Services / Broking
# 4           IT-Software / Software Services
# 5           IT-Software / Software Services
#
#                                       jobdescription         jobid  \
# 0  Job Description   Send me Jobs like this Quali...  210516002263
# 1  Job Description   Send me Jobs like this Quali...  210516002391
# 2  Job Description   Send me Jobs like this - as ...  101016900534
# 3  Job Description   Send me Jobs like this - Inv...   81016900536
# 4  Job Description   Send me Jobs like this Pleas...  120916002122
# 5  Job Description   Send me Jobs like this We ar...  131016005070
#
#                                  joblocation_address  \
# 0                                            Chennai
# 1                                            Chennai
# 2                                          Bengaluru
# 3  Mumbai, Bengaluru, Kolkata, Chennai, Coimbator...
# 4                                          Bengaluru
# 5                                          Bengaluru
#
#                                             jobtitle  numberofpositions  \
# 0           Walkin Data Entry Operator (night Shift)                NaN
# 1                 Work Based Onhome Based Part Time.               60.0
# 2                             Pl/sql Developer - SQL                NaN
# 3             Manager/ad/partner - Indirect Tax - CA                NaN
# 4                    JAVA Technical Lead (6-8 yrs) -                4.0
# 5  WALK IN - As400 Developer - Pfsweb Global Serv...                NaN
#
#                           payrate  ... site_name  \
# 0         1,50,000 - 2,25,000 P.A  ...       NaN
# 1  1,50,000 - 2,50,000 P.A. 20000  ...       NaN
# 2      Not Disclosed by Recruiter  ...       NaN
# 3      Not Disclosed by Recruiter  ...       NaN
# 4      Not Disclosed by Recruiter  ...       NaN
# 5      Not Disclosed by Recruiter  ...       NaN
#
#                                   skills                           uniq_id  \
# 0                                   ITES  43b19632647068535437c774b6ca6cf8
# 1                              Marketing  d4c72325e57f89f364812b5ed5a795f0
# 2  IT Software - Application Programming  c47df6f4cfdf5b46f1fd713ba61b9eba
# 3                               Accounts  115d28f140f694dd1cc61c53d03c66ae
# 4  IT Software - Application Programming  a12553fc03bc7bcced8b1bb8963f97b4
# 5  IT Software - Application Programming  8c3af9062ea835b0965779e2c7faac76
#
#   min_exp  max_exp  avg_exp  min_pay_2  max_pay_2   min_pay   max_pay
# 0     0.0      1.0      0.5   150000.0   225000.0  150000.0  225000.0
# 1     0.0      0.0      0.0   150000.0   250000.0  150000.0  250000.0
# 2     4.0      8.0      6.0        NaN        NaN       NaN       NaN
# 3    11.0     15.0     13.0        NaN        NaN       NaN       NaN
# 4     6.0      8.0      7.0        NaN        NaN       NaN       NaN
# 5     2.0      5.0      3.5        NaN        NaN       NaN       NaN
#
# [6 rows x 21 columns]

# %% [markdown]
# ## Now we will clean and perform feature engineering on Experience column and get Minimum and Maximum experience
#
# - Currently there is a single column experience with minimum and maximum values seperated by '-'
# - We need to fetch minimum and maximum values for each record and store in 2 seperate numeric columns

# %%
# Lets first try to split the experience by "-"

df['experience'][0].split('-')
# Out:
# ['0 ', ' 1 yrs']

# %%
# we will create a function to perform this on all rows

def split_exp(exp):
    min_exp=exp.split('-')[0]
    max_exp=exp.split('-')[1]
    return min_exp, max_exp

# %%
# Above we get the error because this columns is not cleaned and there might be values without '-' or with more than 2 values

df['experience'].apply(split_exp)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[297], line 3
#       1 # Above we get the error because this columns is not cleaned and there might be values without '-' or with more than 2 values
# ----> 3 df['experience'].apply(split_exp)
#
# File D:\Akshay\Anaconda\lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File D:\Akshay\Anaconda\lib\site-packages\pandas\core\apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# -> 1123 return self.apply_standard()
#
# File D:\Akshay\Anaconda\lib\site-packages\pandas\core\apply.py:1174, in SeriesApply.apply_standard(self)
#    1172     else:
#    1173         values = obj.astype(object)._values
# -> 1174         mapped = lib.map_infer(
#    1175             values,
#    1176             f,
#    1177             convert=self.convert_dtype,
#    1178         )
#    1180 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1181     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1182     #  See also GH#25959 regarding EA support
#    1183     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File D:\Akshay\Anaconda\lib\site-packages\pandas\_libs\lib.pyx:2924, in pandas._libs.lib.map_infer()
#
# Cell In[296], line 5, in split_exp(exp)
#       3 def split_exp(exp):
#       4     min_exp=exp.split('-')[0]
# ----> 5     max_exp=exp.split('-')[1]
#       6     return min_exp, max_exp
#
# IndexError: list index out of range

# %%
# Lets check for all those cases where the above funcion fails
len1=[]
for exp in df['experience'].dropna():
    if len(exp.split('-'))!=2:
        len1.append(exp)
        
        
len1
# Out:
# ['Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  '3 - -1 yrs',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned']

# %% [markdown]
# - There are 2 approaches to deal with this, first we can delete all these records but this is not an optimal way.
# - Other than that we can have some ways to clean this up:
# - 1. Use split function and seperate it out as we did with payrate feature
# - 2. Try to enhance your function to handle these kind of exceptions

# %%
# we will modify our function to handle the exceptions and return the values in series format which can be easily 
# appended in df dataframe

def split_exp2(exp):
    try:
        if len(exp.split('-'))==2:
            min_exp=exp.split('-')[0]
            max_exp=exp.split('-')[1]
        return pd.Series([min_exp, max_exp])
    except:
        return pd.Series([np.nan, np.nan])

# %%
df[['min_exp','max_exp']]=df['experience'].apply(split_exp2).rename(columns={0:'min_exp', 1:'max_exp'})

# %%
df.head(6)
# Out:
#                                       company  \
# 0                            MM Media Pvt Ltd
# 1                          find live infotech
# 2         Softtech Career Infosystem Pvt. Ltd
# 3                      Onboard HRServices LLP
# 4  Spire Technologies and Solutions Pvt. Ltd.
# 5             PFS Web Global Services Pvt Ltd
#
#                                            education   experience  \
# 0  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    0 - 1 yrs
# 1  UG: B.Tech/B.E. - Any Specialization PG:MBA/PG...    0 - 0 yrs
# 2  UG: Any Graduate - Any Specialization PG:Any P...    4 - 8 yrs
# 3  UG: Any Graduate - Any Specialization PG:CA Do...  11 - 15 yrs
# 4  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    6 - 8 yrs
# 5  UG: B.Tech/B.E. - Any Specialization PG:MCA - ...    2 - 5 yrs
#
#                                    industry  \
# 0          Media / Entertainment / Internet
# 1  Advertising / PR / MR / Event Management
# 2           IT-Software / Software Services
# 3    Banking / Financial Services / Broking
# 4           IT-Software / Software Services
# 5           IT-Software / Software Services
#
#                                       jobdescription         jobid  \
# 0  Job Description   Send me Jobs like this Quali...  210516002263
# 1  Job Description   Send me Jobs like this Quali...  210516002391
# 2  Job Description   Send me Jobs like this - as ...  101016900534
# 3  Job Description   Send me Jobs like this - Inv...   81016900536
# 4  Job Description   Send me Jobs like this Pleas...  120916002122
# 5  Job Description   Send me Jobs like this We ar...  131016005070
#
#                                  joblocation_address  \
# 0                                            Chennai
# 1                                            Chennai
# 2                                          Bengaluru
# 3  Mumbai, Bengaluru, Kolkata, Chennai, Coimbator...
# 4                                          Bengaluru
# 5                                          Bengaluru
#
#                                             jobtitle  numberofpositions  \
# 0           Walkin Data Entry Operator (night Shift)                NaN
# 1                 Work Based Onhome Based Part Time.               60.0
# 2                             Pl/sql Developer - SQL                NaN
# 3             Manager/ad/partner - Indirect Tax - CA                NaN
# 4                    JAVA Technical Lead (6-8 yrs) -                4.0
# 5  WALK IN - As400 Developer - Pfsweb Global Serv...                NaN
#
#                           payrate  ... site_name  \
# 0         1,50,000 - 2,25,000 P.A  ...       NaN
# 1  1,50,000 - 2,50,000 P.A. 20000  ...       NaN
# 2      Not Disclosed by Recruiter  ...       NaN
# 3      Not Disclosed by Recruiter  ...       NaN
# 4      Not Disclosed by Recruiter  ...       NaN
# 5      Not Disclosed by Recruiter  ...       NaN
#
#                                   skills                           uniq_id  \
# 0                                   ITES  43b19632647068535437c774b6ca6cf8
# 1                              Marketing  d4c72325e57f89f364812b5ed5a795f0
# 2  IT Software - Application Programming  c47df6f4cfdf5b46f1fd713ba61b9eba
# 3                               Accounts  115d28f140f694dd1cc61c53d03c66ae
# 4  IT Software - Application Programming  a12553fc03bc7bcced8b1bb8963f97b4
# 5  IT Software - Application Programming  8c3af9062ea835b0965779e2c7faac76
#
#   min_exp  max_exp avg_exp  min_pay_2  max_pay_2   min_pay   max_pay
# 0      0     1 yrs     0.5   150000.0   225000.0  150000.0  225000.0
# 1      0     0 yrs     0.0   150000.0   250000.0  150000.0  250000.0
# 2      4     8 yrs     6.0        NaN        NaN       NaN       NaN
# 3     11    15 yrs    13.0        NaN        NaN       NaN       NaN
# 4      6     8 yrs     7.0        NaN        NaN       NaN       NaN
# 5      2     5 yrs     3.5        NaN        NaN       NaN       NaN
#
# [6 rows x 21 columns]

# %%
df['max_exp']=df['max_exp'].str.replace('yrs','')
df.head(5)
# Out:
#                                       company  \
# 0                            MM Media Pvt Ltd
# 1                          find live infotech
# 2         Softtech Career Infosystem Pvt. Ltd
# 3                      Onboard HRServices LLP
# 4  Spire Technologies and Solutions Pvt. Ltd.
#
#                                            education   experience  \
# 0  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    0 - 1 yrs
# 1  UG: B.Tech/B.E. - Any Specialization PG:MBA/PG...    0 - 0 yrs
# 2  UG: Any Graduate - Any Specialization PG:Any P...    4 - 8 yrs
# 3  UG: Any Graduate - Any Specialization PG:CA Do...  11 - 15 yrs
# 4  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    6 - 8 yrs
#
#                                    industry  \
# 0          Media / Entertainment / Internet
# 1  Advertising / PR / MR / Event Management
# 2           IT-Software / Software Services
# 3    Banking / Financial Services / Broking
# 4           IT-Software / Software Services
#
#                                       jobdescription         jobid  \
# 0  Job Description   Send me Jobs like this Quali...  210516002263
# 1  Job Description   Send me Jobs like this Quali...  210516002391
# 2  Job Description   Send me Jobs like this - as ...  101016900534
# 3  Job Description   Send me Jobs like this - Inv...   81016900536
# 4  Job Description   Send me Jobs like this Pleas...  120916002122
#
#                                  joblocation_address  \
# 0                                            Chennai
# 1                                            Chennai
# 2                                          Bengaluru
# 3  Mumbai, Bengaluru, Kolkata, Chennai, Coimbator...
# 4                                          Bengaluru
#
#                                    jobtitle  numberofpositions  \
# 0  Walkin Data Entry Operator (night Shift)                NaN
# 1        Work Based Onhome Based Part Time.               60.0
# 2                    Pl/sql Developer - SQL                NaN
# 3    Manager/ad/partner - Indirect Tax - CA                NaN
# 4           JAVA Technical Lead (6-8 yrs) -                4.0
#
#                           payrate  ... site_name  \
# 0         1,50,000 - 2,25,000 P.A  ...       NaN
# 1  1,50,000 - 2,50,000 P.A. 20000  ...       NaN
# 2      Not Disclosed by Recruiter  ...       NaN
# 3      Not Disclosed by Recruiter  ...       NaN
# 4      Not Disclosed by Recruiter  ...       NaN
#
#                                   skills                           uniq_id  \
# 0                                   ITES  43b19632647068535437c774b6ca6cf8
# 1                              Marketing  d4c72325e57f89f364812b5ed5a795f0
# 2  IT Software - Application Programming  c47df6f4cfdf5b46f1fd713ba61b9eba
# 3                               Accounts  115d28f140f694dd1cc61c53d03c66ae
# 4  IT Software - Application Programming  a12553fc03bc7bcced8b1bb8963f97b4
#
#   min_exp max_exp avg_exp  min_pay_2  max_pay_2   min_pay   max_pay
# 0      0       1      0.5   150000.0   225000.0  150000.0  225000.0
# 1      0       0      0.0   150000.0   250000.0  150000.0  250000.0
# 2      4       8      6.0        NaN        NaN       NaN       NaN
# 3     11      15     13.0        NaN        NaN       NaN       NaN
# 4      6       8      7.0        NaN        NaN       NaN       NaN
#
# [5 rows x 21 columns]

# %%
df.dtypes
# Out:
# company                 object
# education               object
# experience              object
# industry                object
# jobdescription          object
# jobid                    int64
# joblocation_address     object
# jobtitle                object
# numberofpositions      float64
# payrate                 object
# postdate                object
# site_name               object
# skills                  object
# uniq_id                 object
# min_exp                 object
# max_exp                 object
# avg_exp                float64
# min_pay_2              float64
# max_pay_2              float64
# min_pay                float64
# max_pay                float64
# dtype: object

# %%
# Convert the column types from object to float

df['min_exp']=df['min_exp'].astype(float)
df['max_exp']=df['max_exp'].astype(float)

df.dtypes
# Out:
# company                 object
# education               object
# experience              object
# industry                object
# jobdescription          object
# jobid                    int64
# joblocation_address     object
# jobtitle                object
# numberofpositions      float64
# payrate                 object
# postdate                object
# site_name               object
# skills                  object
# uniq_id                 object
# min_exp                float64
# max_exp                float64
# avg_exp                float64
# min_pay_2              float64
# max_pay_2              float64
# min_pay                float64
# max_pay                float64
# dtype: object

# %%
# Let's also calculate average experience and payrate

df['avg_exp']=(df['min_exp'] + df['max_exp']) / 2
df['avg_payrate']=(df['min_pay'] + df['max_pay']) / 2

df.head(6)
# Out:
#                                       company  \
# 0                            MM Media Pvt Ltd
# 1                          find live infotech
# 2         Softtech Career Infosystem Pvt. Ltd
# 3                      Onboard HRServices LLP
# 4  Spire Technologies and Solutions Pvt. Ltd.
# 5             PFS Web Global Services Pvt Ltd
#
#                                            education   experience  \
# 0  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    0 - 1 yrs
# 1  UG: B.Tech/B.E. - Any Specialization PG:MBA/PG...    0 - 0 yrs
# 2  UG: Any Graduate - Any Specialization PG:Any P...    4 - 8 yrs
# 3  UG: Any Graduate - Any Specialization PG:CA Do...  11 - 15 yrs
# 4  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    6 - 8 yrs
# 5  UG: B.Tech/B.E. - Any Specialization PG:MCA - ...    2 - 5 yrs
#
#                                    industry  \
# 0          Media / Entertainment / Internet
# 1  Advertising / PR / MR / Event Management
# 2           IT-Software / Software Services
# 3    Banking / Financial Services / Broking
# 4           IT-Software / Software Services
# 5           IT-Software / Software Services
#
#                                       jobdescription         jobid  \
# 0  Job Description   Send me Jobs like this Quali...  210516002263
# 1  Job Description   Send me Jobs like this Quali...  210516002391
# 2  Job Description   Send me Jobs like this - as ...  101016900534
# 3  Job Description   Send me Jobs like this - Inv...   81016900536
# 4  Job Description   Send me Jobs like this Pleas...  120916002122
# 5  Job Description   Send me Jobs like this We ar...  131016005070
#
#                                  joblocation_address  \
# 0                                            Chennai
# 1                                            Chennai
# 2                                          Bengaluru
# 3  Mumbai, Bengaluru, Kolkata, Chennai, Coimbator...
# 4                                          Bengaluru
# 5                                          Bengaluru
#
#                                             jobtitle  numberofpositions  \
# 0           Walkin Data Entry Operator (night Shift)                NaN
# 1                 Work Based Onhome Based Part Time.               60.0
# 2                             Pl/sql Developer - SQL                NaN
# 3             Manager/ad/partner - Indirect Tax - CA                NaN
# 4                    JAVA Technical Lead (6-8 yrs) -                4.0
# 5  WALK IN - As400 Developer - Pfsweb Global Serv...                NaN
#
#                           payrate  ...                                 skills  \
# 0         1,50,000 - 2,25,000 P.A  ...                                   ITES
# 1  1,50,000 - 2,50,000 P.A. 20000  ...                              Marketing
# 2      Not Disclosed by Recruiter  ...  IT Software - Application Programming
# 3      Not Disclosed by Recruiter  ...                               Accounts
# 4      Not Disclosed by Recruiter  ...  IT Software - Application Programming
# 5      Not Disclosed by Recruiter  ...  IT Software - Application Programming
#
#                             uniq_id min_exp max_exp  avg_exp  min_pay_2  \
# 0  43b19632647068535437c774b6ca6cf8     0.0     1.0      0.5   150000.0
# 1  d4c72325e57f89f364812b5ed5a795f0     0.0     0.0      0.0   150000.0
# 2  c47df6f4cfdf5b46f1fd713ba61b9eba     4.0     8.0      6.0        NaN
# 3  115d28f140f694dd1cc61c53d03c66ae    11.0    15.0     13.0        NaN
# 4  a12553fc03bc7bcced8b1bb8963f97b4     6.0     8.0      7.0        NaN
# 5  8c3af9062ea835b0965779e2c7faac76     2.0     5.0      3.5        NaN
#
#    max_pay_2   min_pay   max_pay  avg_payrate
# 0   225000.0  150000.0  225000.0     187500.0
# 1   250000.0  150000.0  250000.0     200000.0
# 2        NaN       NaN       NaN          NaN
# 3        NaN       NaN       NaN          NaN
# 4        NaN       NaN       NaN          NaN
# 5        NaN       NaN       NaN          NaN
#
# [6 rows x 22 columns]

# %%
df.dtypes
# Out:
# company                 object
# education               object
# experience              object
# industry                object
# jobdescription          object
# jobid                    int64
# joblocation_address     object
# jobtitle                object
# numberofpositions      float64
# payrate                 object
# postdate                object
# site_name               object
# skills                  object
# uniq_id                 object
# min_exp                float64
# max_exp                float64
# avg_exp                float64
# min_pay_2              float64
# max_pay_2              float64
# min_pay                float64
# max_pay                float64
# avg_payrate            float64
# dtype: object

# %% [markdown]
# ## Now we will clean and perform feature engineering on Postdate column and get day, date, month and year from this

# %%
# Firsty we need to convert object type to date time for postdate feature. 
# We can convert to datetime64 or M8, which are both similar

np.dtype('datetime64[ns]')==np.dtype('<M8[ns]')
# Out:
# True

# %%
# We will  start with creating a function to fetch day, month and year from postdate

def fetch_dt_att(dataframe,feature):
    try:
        return pd.Series([dataframe[feature].dt.day,dataframe[feature].dt.month,dataframe[feature].dt.year])
    except:
        print('Data type not supported')

# %%
# If we call this function on postdate column now, since it is of Object type it would print exception

fetch_dt_att(df,'postdate')
# Out:
# Data type not supported

# %%
# So, first we need to convert the column from Object type to datetime format

df['postdate']=pd.to_datetime(df['postdate'])

# %%
df['postdate'].dtype
# Out:
# datetime64[ns, UTC]

# %%
df[['day','month','year']]=fetch_dt_att(df,'postdate')

df.head(6)
# Out:
#                                       company  \
# 0                            MM Media Pvt Ltd
# 1                          find live infotech
# 2         Softtech Career Infosystem Pvt. Ltd
# 3                      Onboard HRServices LLP
# 4  Spire Technologies and Solutions Pvt. Ltd.
# 5             PFS Web Global Services Pvt Ltd
#
#                                            education   experience  \
# 0  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    0 - 1 yrs
# 1  UG: B.Tech/B.E. - Any Specialization PG:MBA/PG...    0 - 0 yrs
# 2  UG: Any Graduate - Any Specialization PG:Any P...    4 - 8 yrs
# 3  UG: Any Graduate - Any Specialization PG:CA Do...  11 - 15 yrs
# 4  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    6 - 8 yrs
# 5  UG: B.Tech/B.E. - Any Specialization PG:MCA - ...    2 - 5 yrs
#
#                                    industry  \
# 0          Media / Entertainment / Internet
# 1  Advertising / PR / MR / Event Management
# 2           IT-Software / Software Services
# 3    Banking / Financial Services / Broking
# 4           IT-Software / Software Services
# 5           IT-Software / Software Services
#
#                                       jobdescription         jobid  \
# 0  Job Description   Send me Jobs like this Quali...  210516002263
# 1  Job Description   Send me Jobs like this Quali...  210516002391
# 2  Job Description   Send me Jobs like this - as ...  101016900534
# 3  Job Description   Send me Jobs like this - Inv...   81016900536
# 4  Job Description   Send me Jobs like this Pleas...  120916002122
# 5  Job Description   Send me Jobs like this We ar...  131016005070
#
#                                  joblocation_address  \
# 0                                            Chennai
# 1                                            Chennai
# 2                                          Bengaluru
# 3  Mumbai, Bengaluru, Kolkata, Chennai, Coimbator...
# 4                                          Bengaluru
# 5                                          Bengaluru
#
#                                             jobtitle  numberofpositions  \
# 0           Walkin Data Entry Operator (night Shift)                NaN
# 1                 Work Based Onhome Based Part Time.               60.0
# 2                             Pl/sql Developer - SQL                NaN
# 3             Manager/ad/partner - Indirect Tax - CA                NaN
# 4                    JAVA Technical Lead (6-8 yrs) -                4.0
# 5  WALK IN - As400 Developer - Pfsweb Global Serv...                NaN
#
#                           payrate  ... max_exp avg_exp min_pay_2 max_pay_2  \
# 0         1,50,000 - 2,25,000 P.A  ...     1.0     0.5  150000.0  225000.0
# 1  1,50,000 - 2,50,000 P.A. 20000  ...     0.0     0.0  150000.0  250000.0
# 2      Not Disclosed by Recruiter  ...     8.0     6.0       NaN       NaN
# 3      Not Disclosed by Recruiter  ...    15.0    13.0       NaN       NaN
# 4      Not Disclosed by Recruiter  ...     8.0     7.0       NaN       NaN
# 5      Not Disclosed by Recruiter  ...     5.0     3.5       NaN       NaN
#
#     min_pay   max_pay  avg_payrate   day  month    year
# 0  150000.0  225000.0     187500.0  21.0    5.0  2016.0
# 1  150000.0  250000.0     200000.0  21.0    5.0  2016.0
# 2       NaN       NaN          NaN  13.0   10.0  2016.0
# 3       NaN       NaN          NaN  13.0   10.0  2016.0
# 4       NaN       NaN          NaN  13.0   10.0  2016.0
# 5       NaN       NaN          NaN  13.0   10.0  2016.0
#
# [6 rows x 25 columns]

# %% [markdown]
# ### One of the other ways is to use map function to perform this
#
# - Syntax is map(function, sequence) where map act as an iterator which performs the function on each row of the sequence

# %%
def fetch_dt_att2(x):
    return ([x.day,x.month,x.year])

# %%
fet_date=pd.DataFrame(map(fetch_dt_att2,df['postdate'])).rename(columns={0:'day',1:'month',2:'year'})

# %%
fet_date
# Out:
#         day  month    year
# 0      21.0    5.0  2016.0
# 1      21.0    5.0  2016.0
# 2      13.0   10.0  2016.0
# 3      13.0   10.0  2016.0
# 4      13.0   10.0  2016.0
# ...     ...    ...     ...
# 21995  25.0   11.0  2016.0
# 21996  24.0   11.0  2016.0
# 21997  25.0   11.0  2016.0
# 21998  27.0   11.0  2016.0
# 21999  25.0   11.0  2016.0
#
# [22000 rows x 3 columns]

# %%
pd.concat([df,fet_date],axis=1)
# Out:
#                                                 company  \
# 0                                      MM Media Pvt Ltd
# 1                                    find live infotech
# 2                   Softtech Career Infosystem Pvt. Ltd
# 3                                Onboard HRServices LLP
# 4            Spire Technologies and Solutions Pvt. Ltd.
# ...                                                 ...
# 21995       Morgan Stanley Advantage Services Pvt. Ltd.
# 21996  Careernet Technologies Pvt Ltd hiring for Client
# 21997                                    Musk - Startup
# 21998                                      Confidential
# 21999                   Cambio Consulting India Pvt Ltd
#
#                                                education   experience  \
# 0      UG: B.Tech/B.E. - Any Specialization PG:Any Po...    0 - 1 yrs
# 1      UG: B.Tech/B.E. - Any Specialization PG:MBA/PG...    0 - 0 yrs
# 2      UG: Any Graduate - Any Specialization PG:Any P...    4 - 8 yrs
# 3      UG: Any Graduate - Any Specialization PG:CA Do...  11 - 15 yrs
# 4      UG: B.Tech/B.E. - Any Specialization PG:Any Po...    6 - 8 yrs
# ...                                                  ...          ...
# 21995              UG: Any Graduate - Any Specialization   9 - 13 yrs
# 21996  UG: B.Tech/B.E. - Any Specialization PG:M.Tech...    3 - 5 yrs
# 21997  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    2 - 4 yrs
# 21998  UG: B.Tech/B.E. - Any Specialization PG:MCA - ...   7 - 12 yrs
# 21999  UG: B.Tech/B.E. - Any Specialization PG:MCA - ...   5 - 10 yrs
#
#                                        industry  \
# 0              Media / Entertainment / Internet
# 1      Advertising / PR / MR / Event Management
# 2               IT-Software / Software Services
# 3        Banking / Financial Services / Broking
# 4               IT-Software / Software Services
# ...                                         ...
# 21995    Banking / Financial Services / Broking
# 21996           IT-Software / Software Services
# 21997                      Internet / Ecommerce
# 21998           IT-Software / Software Services
# 21999           IT-Software / Software Services
#
#                                           jobdescription         jobid  \
# 0      Job Description   Send me Jobs like this Quali...  210516002263
# 1      Job Description   Send me Jobs like this Quali...  210516002391
# 2      Job Description   Send me Jobs like this - as ...  101016900534
# 3      Job Description   Send me Jobs like this - Inv...   81016900536
# 4      Job Description   Send me Jobs like this Pleas...  120916002122
# ...                                                  ...           ...
# 21995  Job Description   Send me Jobs like this Greet...  241116007152
# 21996  Job Description   Send me Jobs like this Looki...  241116001104
# 21997  Job Description   Send me Jobs like this Work ...  251116900644
# 21998  Job Description   Send me Jobs like this We ar...  231116901329
# 21999  Job Description   Send me Jobs like this Job d...  251116003840
#
#                                      joblocation_address  \
# 0                                                Chennai
# 1                                                Chennai
# 2                                              Bengaluru
# 3      Mumbai, Bengaluru, Kolkata, Chennai, Coimbator...
# 4                                              Bengaluru
# ...                                                  ...
# 21995                                          Bengaluru
# 21996                                 Bengaluru, Gurgaon
# 21997                                          Bengaluru
# 21998                               Delhi NCR, Bengaluru
# 21999                                          Bengaluru
#
#                                                 jobtitle  numberofpositions  \
# 0               Walkin Data Entry Operator (night Shift)                NaN
# 1                     Work Based Onhome Based Part Time.               60.0
# 2                                 Pl/sql Developer - SQL                NaN
# 3                 Manager/ad/partner - Indirect Tax - CA                NaN
# 4                        JAVA Technical Lead (6-8 yrs) -                4.0
# ...                                                  ...                ...
# 21995  Quality Assurance - VP with Morgan Stanley Ban...                2.0
# 21996      Java Backend Developers for a Product Company                NaN
# 21997                    Full Stack Development Engineer                NaN
# 21998  Sr UI Developer/ Technical Lead - Html/ CSS/ J...                NaN
# 21999                              RF Firmware Engineers                NaN
#
#                               payrate  ...  max_pay_2    min_pay    max_pay  \
# 0             1,50,000 - 2,25,000 P.A  ...   225000.0   150000.0   225000.0
# 1      1,50,000 - 2,50,000 P.A. 20000  ...   250000.0   150000.0   250000.0
# 2          Not Disclosed by Recruiter  ...        NaN        NaN        NaN
# 3          Not Disclosed by Recruiter  ...        NaN        NaN        NaN
# 4          Not Disclosed by Recruiter  ...        NaN        NaN        NaN
# ...                               ...  ...        ...        ...        ...
# 21995      Not Disclosed by Recruiter  ...        NaN        NaN        NaN
# 21996        8,50,000 - 14,00,000 P.A  ...  1400000.0   850000.0  1400000.0
# 21997      Not Disclosed by Recruiter  ...        NaN        NaN        NaN
# 21998      Not Disclosed by Recruiter  ...        NaN        NaN        NaN
# 21999       12,00,000 - 22,00,000 P.A  ...  2200000.0  1200000.0  2200000.0
#
#       avg_payrate   day  month    year   day  month    year
# 0        187500.0  21.0    5.0  2016.0  21.0    5.0  2016.0
# 1        200000.0  21.0    5.0  2016.0  21.0    5.0  2016.0
# 2             NaN  13.0   10.0  2016.0  13.0   10.0  2016.0
# 3             NaN  13.0   10.0  2016.0  13.0   10.0  2016.0
# 4             NaN  13.0   10.0  2016.0  13.0   10.0  2016.0
# ...           ...   ...    ...     ...   ...    ...     ...
# 21995         NaN  25.0   11.0  2016.0  25.0   11.0  2016.0
# 21996   1125000.0  24.0   11.0  2016.0  24.0   11.0  2016.0
# 21997         NaN  25.0   11.0  2016.0  25.0   11.0  2016.0
# 21998         NaN  27.0   11.0  2016.0  27.0   11.0  2016.0
# 21999   1700000.0  25.0   11.0  2016.0  25.0   11.0  2016.0
#
# [22000 rows x 28 columns]

# %% [markdown]
# ## Now we will clean and perform feature engineering on Job Location column

# %%
df.columns
# Out:
# Index(['company', 'education', 'experience', 'industry', 'jobdescription',
#        'jobid', 'joblocation_address', 'jobtitle', 'numberofpositions',
#        'payrate', 'postdate', 'site_name', 'skills', 'uniq_id', 'min_exp',
#        'max_exp', 'avg_exp', 'min_pay_2', 'max_pay_2', 'min_pay', 'max_pay',
#        'avg_payrate', 'day', 'month', 'year'],
#       dtype='object')

# %%
# Lets first see distinct values from the column Job Location

df['joblocation_address']
# Out:
# 0                                                  Chennai
# 1                                                  Chennai
# 2                                                Bengaluru
# 3        Mumbai, Bengaluru, Kolkata, Chennai, Coimbator...
# 4                                                Bengaluru
#                                ...
# 21995                                            Bengaluru
# 21996                                   Bengaluru, Gurgaon
# 21997                                            Bengaluru
# 21998                                 Delhi NCR, Bengaluru
# 21999                                            Bengaluru
# Name: joblocation_address, Length: 22000, dtype: object

# %%
# Lets see the value counts for each value

df['joblocation_address'].value_counts()
# Out:
# Bengaluru/Bangalore                                                                          3775
# Mumbai                                                                                       2348
# Bengaluru                                                                                    1453
# Hyderabad / Secunderabad                                                                     1246
# Chennai                                                                                      1204
#                                                                                              ...
# Delhi/NCR(National Capital Region) , Ernakulam / Kochi/ Cochin , Kanpur , Kolkata , Nasik       1
# Gurgaon , Noida , Delhi                                                                         1
# Pune , Noida                                                                                    1
# Pune , Delhi , Bengaluru/Bangalore                                                              1
# Bengaluru, Malaysia                                                                             1
# Name: joblocation_address, Length: 2329, dtype: int64

# %%
# Lets try to restrict it for top 10 values only

df['joblocation_address'].value_counts().head(10)
# Out:
# Bengaluru/Bangalore         3775
# Mumbai                      2348
# Bengaluru                   1453
# Hyderabad / Secunderabad    1246
# Chennai                     1204
# Hyderabad                    936
# Noida                        775
# Delhi                        763
# Gurgaon                      743
# Mumbai , Mumbai              514
# Name: joblocation_address, dtype: int64

# %% [markdown]
# - As we can see there are multiple rows for values like Bangalore or Hyderabad which we need to clean
# - To perform the cleaning, first we would create a copy of the data

# %%
data=df.copy()

# %%
# Lets see distinct values

data['joblocation_address'].unique()
# Out:
# array(['Chennai', 'Bengaluru',
#        'Mumbai, Bengaluru, Kolkata, Chennai, Coimbatore, Tamilnadu', ...,
#        'Mumbai, Bengaluru, Hyderabad, Kolkata',
#        'Mumbai, Chennai, Delhi, Bengaluru, Hyderabad, Pune',
#        'Bengaluru, Malaysia'], dtype=object)

# %%
# Now we need to replace the values like "Bengaluru/Bangalore" with "Bengaluru" to make the data consistent
# For this we need to have dictionary which can be used where key would be old value and value would be new value
# We already have this combincation in a CSV file which we would upload
# To convert into dictionary we would make first column as index

rep=pd.read_csv(r'D:\Akshay\Python Projects\Naukri.com Analysis\Datasets/replacements.csv').set_index('Unnamed: 0')
rep
# Out:
#                                                    joblocation_address
# Unnamed: 0
#  Delhi/NCR(National Capital Region)                              Delhi
#  Delhi/NCR(National Capital Region)                              Delhi
# (Bengaluru/Bangalore)                                        Bangalore
# Bangalore                                                    Bangalore
# Bangalore , Bangalore / Bangalore                            Bangalore
# Bangalore Bangalore                                          Bangalore
# Bangalore,Bangalore / Bangalore                              Bangalore
# Bangalore,karnataka                                          Bangalore
# Bengaluru                                                    Bangalore
# Bengaluru/Bangalore                                          Bangalore
# Bengaluru/Bangalore , bangalore                              Bangalore
# DELHI(NATIONAL CAPITAL REGION)                                   Delhi
# Delhi                                                            Delhi
# Delhi , Delhi                                                    Delhi
# Delhi , Delhi/Greater Delhi                                      Delhi
# Delhi , Delhi/NCR(National Capital Region)                       Delhi
# Delhi NCR                                                        Delhi
# Delhi(National Capital Region)                                   Delhi
# Delhi(National Capital Region) , Delhi                           Delhi
# Delhi,Delhi                                                      Delhi
# Delhi/NCR                                                        Delhi
# Delhi/NCR(National Capital Region)                               Delhi
# Delhi/NCR(National Capital Region)                               Delhi
# Delhi/NCR(National Capital Region) , Delhi                       Delhi
# Delhi/NCR(National Capital Region) , Gurgaon , ...               Delhi
# Delhi/NCR(National Capital Region) , Noida                       Delhi
# Delhi/NCR(National Capital Region),Gurgaon                       Delhi
# Ghaziabad                                                        Delhi
# Gurgaon                                                          Delhi
# Gurgaon , Delhi/NCR(National Capital Region)                     Delhi
# Gurgaon , Gurgaon                                                Delhi
# Hyderabad / Secunderabad                                     Hyderabad
# Hyderabad / Secunderabad , Hyderabad/Secunderabad            Hyderabad
# Mumbai , Mumbai                                                 Mumbai
# Mumbai, maharashtra                                             Mumbai
# NCR,NCR                                                          Delhi
# Noida                                                            Delhi
# Noida , Noida/Greater Noida                                      Delhi
# Noida/Greater Noida                                              Delhi

# %%
replacement_dict=rep.to_dict()
replacement_dict
# Out:
# {'joblocation_address': {' Delhi/NCR(National Capital Region)': 'Delhi',
#   ' Delhi/NCR(National Capital Region) ': 'Delhi',
#   '(Bengaluru/Bangalore)': 'Bangalore',
#   'Bangalore': 'Bangalore',
#   'Bangalore , Bangalore / Bangalore': 'Bangalore',
#   'Bangalore Bangalore': 'Bangalore',
#   'Bangalore,Bangalore / Bangalore': 'Bangalore',
#   'Bangalore,karnataka': 'Bangalore',
#   'Bengaluru': 'Bangalore',
#   'Bengaluru/Bangalore ': 'Bangalore',
#   'Bengaluru/Bangalore , bangalore': 'Bangalore',
#   'DELHI(NATIONAL CAPITAL REGION)': 'Delhi',
#   'Delhi': 'Delhi',
#   'Delhi , Delhi': 'Delhi',
#   'Delhi , Delhi/Greater Delhi': 'Delhi',
#   'Delhi , Delhi/NCR(National Capital Region)': 'Delhi',
#   'Delhi NCR': 'Delhi',
#   'Delhi(National Capital Region)': 'Delhi',
#   'Delhi(National Capital Region) , Delhi': 'Delhi',
#   'Delhi,Delhi': 'Delhi',
#   'Delhi/NCR': 'Delhi',
#   'Delhi/NCR(National Capital Region)': 'Delhi',
#   'Delhi/NCR(National Capital Region) ': 'Delhi',
#   'Delhi/NCR(National Capital Region) , Delhi': 'Delhi',
#   'Delhi/NCR(National Capital Region) , Gurgaon , Noida': 'Delhi',
#   'Delhi/NCR(National Capital Region) , Noida': 'Delhi',
#   'Delhi/NCR(National Capital Region),Gurgaon': 'Delhi',
#   'Ghaziabad': 'Delhi',
#   'Gurgaon': 'Delhi',
#   'Gurgaon , Delhi/NCR(National Capital Region)': 'Delhi',
#   'Gurgaon , Gurgaon': 'Delhi',
#   'Hyderabad / Secunderabad': 'Hyderabad',
#   'Hyderabad / Secunderabad , Hyderabad/Secunderabad': 'Hyderabad',
#   'Mumbai , Mumbai': 'Mumbai',
#   'Mumbai, maharashtra': 'Mumbai',
#   'NCR,NCR': 'Delhi',
#   'Noida': 'Delhi',
#   'Noida , Noida/Greater Noida': 'Delhi',
#   'Noida/Greater Noida': 'Delhi'}}

# %%
# Now we would just replace the values as per the dictionary using replace function

data.replace(replacement_dict, inplace=True, regex=True)

# %%
data['joblocation_address'].value_counts()
# Out:
# Bangalore                                                                                           5228
# Mumbai                                                                                              2887
# Delhi                                                                                               2741
# Hyderabad                                                                                           2182
# Chennai                                                                                             1204
#                                                                                                     ...
# Delhi , Delhi , Faridabad                                                                              1
# Bangalore , Delhi(National Capital Region) , Delhi , Ahmedabad , Delhi                                 1
# Ernakulam / Kochi/ Cochin , Trivandrum , Jaipur , Delhi , Delhi(National Capital Region) , Delhi       1
# Mathura , Delhi , Delhi                                                                                1
# Bangalore, Malaysia                                                                                    1
# Name: joblocation_address, Length: 2141, dtype: int64

# %%
# We can also filter out dataset for a particular location

filter=df['joblocation_address']=='Chennai'
loc_chennai=df[filter]
loc_chennai
# Out:
#                                             company  \
# 0                                  MM Media Pvt Ltd
# 1                                find live infotech
# 3621       Cognizant Technology Solutions India Ltd
# 3622       Cognizant Technology Solutions India Ltd
# 3623                     Satincorp Technologies Inc
# ...                                             ...
# 18194                                Talent Maximus
# 18195                               Ken QA Services
# 18196             Saaki Argus And Averil Consulting
# 18197          Financial Software Systems Pvt. Ltd.
# 20834  Vimbri Media Pvt. Ltd. (The Dollar Business)
#
#                                                education experience  \
# 0      UG: B.Tech/B.E. - Any Specialization PG:Any Po...  0 - 1 yrs
# 1      UG: B.Tech/B.E. - Any Specialization PG:MBA/PG...  0 - 0 yrs
# 3621   UG: B.Tech/B.E. PG:Post Graduation Not Require...  3 - 5 yrs
# 3622   UG: B.Tech/B.E. PG:Post Graduation Not Require...  2 - 5 yrs
# 3623   UG: Any Graduate PG:MBA/PGDM Doctorate:Any Doc...  5 - 8 yrs
# ...                                                  ...        ...
# 18194  UG: B.Tech/B.E. - Any Specialization PG:MCA - ...  1 - 3 yrs
# 18195  UG: Any Graduate - Any Specialization PG:Any P...  4 - 8 yrs
# 18196  UG: Any Graduate - Any Specialization, Graduat...  3 - 8 yrs
# 18197  UG: Any Graduate - Any Specialization, Any Spe...  2 - 6 yrs
# 20834              UG: Any Graduate - Any Specialization  1 - 3 yrs
#
#                                        industry  \
# 0              Media / Entertainment / Internet
# 1      Advertising / PR / MR / Event Management
# 3621            IT-Software / Software Services
# 3622            IT-Software / Software Services
# 3623            IT-Software / Software Services
# ...                                         ...
# 18194                                     Other
# 18195           IT-Software / Software Services
# 18196           IT-Software / Software Services
# 18197           IT-Software / Software Services
# 20834          Media / Entertainment / Internet
#
#                                           jobdescription         jobid  \
# 0      Job Description   Send me Jobs like this Quali...  210516002263
# 1      Job Description   Send me Jobs like this Quali...  210516002391
# 3621   Job Description   Send me Jobs like this Techn...  130516501929
# 3622   Job Description   Send me Jobs like this Under...  130516501917
# 3623   Job Description   Send me Jobs like this The c...  130516503864
# ...                                                  ...           ...
# 18194  Job Description   Send me Jobs like this 1. Co...  250316001401
# 18195  Job Description   Send me Jobs like this Skill...  200516900845
# 18196  Job Description   Send me Jobs like this Job D...  200516003885
# 18197  Job Description   Send me Jobs like this Issui...  310316004720
# 20834  Job Description   Send me Jobs like this Minim...   61216001516
#
#       joblocation_address                                           jobtitle  \
# 0                 Chennai           Walkin Data Entry Operator (night Shift)
# 1                 Chennai                 Work Based Onhome Based Part Time.
# 3621              Chennai                           Sr. Associate - Projects
# 3622              Chennai                              Technology Specialist
# 3623              Chennai                                  marketing manager
# ...                   ...                                                ...
# 18194             Chennai                                  Software Engineer
# 18195             Chennai                Test Automation Engineer - Selenium
# 18196             Chennai                             ETL Automation Testing
# 18197             Chennai                          Software Testing Engineer
# 20834             Chennai  Spot Offers for Field Sales / Business Develop...
#
#        numberofpositions                         payrate  ... max_exp avg_exp  \
# 0                    NaN         1,50,000 - 2,25,000 P.A  ...     1.0     0.5
# 1                   60.0  1,50,000 - 2,50,000 P.A. 20000  ...     0.0     0.0
# 3621                 NaN      Not Disclosed by Recruiter  ...     5.0     4.0
# 3622                 NaN      Not Disclosed by Recruiter  ...     5.0     3.5
# 3623                 NaN      Not Disclosed by Recruiter  ...     8.0     6.5
# ...                  ...                             ...  ...     ...     ...
# 18194                NaN      Not Disclosed by Recruiter  ...     3.0     2.0
# 18195                4.0      Not Disclosed by Recruiter  ...     8.0     6.0
# 18196                NaN         4,00,000 - 9,00,000 P.A  ...     8.0     5.5
# 18197                6.0      Not Disclosed by Recruiter  ...     6.0     4.0
# 20834                NaN         2,00,000 - 3,00,000 P.A  ...     3.0     2.0
#
#       min_pay_2 max_pay_2   min_pay   max_pay  avg_payrate   day  month  \
# 0      150000.0  225000.0  150000.0  225000.0     187500.0  21.0    5.0
# 1      150000.0  250000.0  150000.0  250000.0     200000.0  21.0    5.0
# 3621        NaN       NaN       NaN       NaN          NaN  13.0    5.0
# 3622        NaN       NaN       NaN       NaN          NaN  13.0    5.0
# 3623        NaN       NaN       NaN       NaN          NaN  13.0    5.0
# ...         ...       ...       ...       ...          ...   ...    ...
# 18194       NaN       NaN       NaN       NaN          NaN  20.0    5.0
# 18195       NaN       NaN       NaN       NaN          NaN  20.0    5.0
# 18196  400000.0  900000.0  400000.0  900000.0     650000.0  20.0    5.0
# 18197       NaN       NaN       NaN       NaN          NaN  20.0    5.0
# 20834  200000.0  300000.0  200000.0  300000.0     250000.0   9.0    1.0
#
#          year
# 0      2016.0
# 1      2016.0
# 3621   2016.0
# 3622   2016.0
# 3623   2016.0
# ...       ...
# 18194  2016.0
# 18195  2016.0
# 18196  2016.0
# 18197  2016.0
# 20834  2017.0
#
# [1204 rows x 25 columns]

# %%
# Also we can compare the values before and after the replacement 

df['joblocation_address'].nunique()
# Out:
# 2329

# %%
data['joblocation_address'].nunique()
# Out:
# 2141

# %% [markdown]
# ## Now lets prepare our final data by removing redundant columns

# %%
data.columns
# Out:
# Index(['company', 'education', 'experience', 'industry', 'jobdescription',
#        'jobid', 'joblocation_address', 'jobtitle', 'numberofpositions',
#        'payrate', 'postdate', 'site_name', 'skills', 'uniq_id', 'min_exp',
#        'max_exp', 'avg_exp', 'min_pay_2', 'max_pay_2', 'min_pay', 'max_pay',
#        'avg_payrate', 'day', 'month', 'year'],
#       dtype='object')

# %%
# Lets create a function to drop columns

def drop_feature(column):
    data.drop(column,axis=1,inplace=True)

# %%
drop_feature('payrate')

# %%
drop_feature('experience')

# %%
drop_feature('postdate')
drop_feature('uniq_id')
drop_feature('min_pay_2')
drop_feature('max_pay_2')

data.columns
# Out:
# Index(['company', 'education', 'industry', 'jobdescription', 'jobid',
#        'joblocation_address', 'jobtitle', 'numberofpositions', 'site_name',
#        'skills', 'min_exp', 'max_exp', 'avg_exp', 'min_pay', 'max_pay',
#        'avg_payrate', 'day', 'month', 'year'],
#       dtype='object')

# %%
data.head(6)
# Out:
#                                       company  \
# 0                            MM Media Pvt Ltd
# 1                          find live infotech
# 2         Softtech Career Infosystem Pvt. Ltd
# 3                      Onboard HRServices LLP
# 4  Spire Technologies and Solutions Pvt. Ltd.
# 5             PFS Web Global Services Pvt Ltd
#
#                                            education  \
# 0  UG: B.Tech/B.E. - Any Specialization PG:Any Po...
# 1  UG: B.Tech/B.E. - Any Specialization PG:MBA/PG...
# 2  UG: Any Graduate - Any Specialization PG:Any P...
# 3  UG: Any Graduate - Any Specialization PG:CA Do...
# 4  UG: B.Tech/B.E. - Any Specialization PG:Any Po...
# 5  UG: B.Tech/B.E. - Any Specialization PG:MCA - ...
#
#                                    industry  \
# 0          Media / Entertainment / Internet
# 1  Advertising / PR / MR / Event Management
# 2           IT-Software / Software Services
# 3    Banking / Financial Services / Broking
# 4           IT-Software / Software Services
# 5           IT-Software / Software Services
#
#                                       jobdescription         jobid  \
# 0  Job Description   Send me Jobs like this Quali...  210516002263
# 1  Job Description   Send me Jobs like this Quali...  210516002391
# 2  Job Description   Send me Jobs like this - as ...  101016900534
# 3  Job Description   Send me Jobs like this - Inv...   81016900536
# 4  Job Description   Send me Jobs like this Pleas...  120916002122
# 5  Job Description   Send me Jobs like this We ar...  131016005070
#
#                                  joblocation_address  \
# 0                                            Chennai
# 1                                            Chennai
# 2                                          Bangalore
# 3  Mumbai, Bangalore, Kolkata, Chennai, Coimbator...
# 4                                          Bangalore
# 5                                          Bangalore
#
#                                             jobtitle  numberofpositions  \
# 0           Walkin Data Entry Operator (night Shift)                NaN
# 1                 Work Based Onhome Based Part Time.               60.0
# 2                             Pl/sql Developer - SQL                NaN
# 3             Manager/ad/partner - Indirect Tax - CA                NaN
# 4                    JAVA Technical Lead (6-8 yrs) -                4.0
# 5  WALK IN - As400 Developer - Pfsweb Global Serv...                NaN
#
#   site_name                                 skills  min_exp  max_exp  avg_exp  \
# 0       NaN                                   ITES      0.0      1.0      0.5
# 1       NaN                              Marketing      0.0      0.0      0.0
# 2       NaN  IT Software - Application Programming      4.0      8.0      6.0
# 3       NaN                               Accounts     11.0     15.0     13.0
# 4       NaN  IT Software - Application Programming      6.0      8.0      7.0
# 5       NaN  IT Software - Application Programming      2.0      5.0      3.5
#
#     min_pay   max_pay  avg_payrate   day  month    year
# 0  150000.0  225000.0     187500.0  21.0    5.0  2016.0
# 1  150000.0  250000.0     200000.0  21.0    5.0  2016.0
# 2       NaN       NaN          NaN  13.0   10.0  2016.0
# 3       NaN       NaN          NaN  13.0   10.0  2016.0
# 4       NaN       NaN          NaN  13.0   10.0  2016.0
# 5       NaN       NaN          NaN  13.0   10.0  2016.0

# %%
# Now lets save this data in form of CSV file

data.to_csv(r'D:\Akshay\Python Projects\Naukri.com Analysis\Datasets/naukri_data.csv', index=False)
